# %%
# 필요패키지 import
import time
import json
import urllib
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup

# %%
#전처리 데이터 불러오기
df = pd.read_csv('./raw220628.csv',
                 encoding='utf-8')

# %%
df = pd.DataFrame({
    '#': [ i+1 for i in range(0,1113)],
    'nickname': df['Column2'],
    }, columns=['#','nickname'])

# %%
df
# Out:
#          #       nickname
# 0        1            턱돼지
# 1        2       핑찍으면우물잠수
# 2        3  Visual Jockey
# 3        4            이원일
# 4        5           mvp맨
# ...    ...            ...
# 1108  1109        관악산오리백숙
# 1109  1110           T1테뒤
# 1110  1111         문란한사생활
# 1111  1112          카와이민성
# 1112  1113          콜라마신다
#
# [1113 rows x 2 columns]

# %%
data = []

# %%
def data_crawling(user_name):
#DB 유저 불러오기
    url = f'https://your.gg/kr/profile/{user_name}'
    resp = requests.get(url)
    html = BeautifulSoup(resp.text, 'html.parser')
#승패 크롤링
    for i in range(30):
        # 티어 크롤링
        # buiiz7-0 sc-1p3os9u-3 hCTbNr zMKXD
        ingame_id = html.select('div.sc-15xrq75-3 span')[0].text.strip()
        tier = html.select('div span.sc-1p3os9u-3')[0].text.strip()
        # 승, 패 크롤링
        # buiiz7-0 d490eh-4 hCTbML dSQenp
        Win_lose = html.select('span.d490eh-4')[i].text
        # KDA 크롤링
        # buiiz7-0 sc-1p49g2y-1 hNEJCS gLFnks
        KDA = html.select('span.sc-1p49g2y-1')[i*3].text[:-7]
        kill = KDA.split('/')[0]
        death =  KDA.split('/')[1]
        assist = KDA.split('/')[2]
        # 게임 시간 크롤링
        # buiiz7-0 d490eh-5 hNEJEN
        game_time = html.select('span.d490eh-5')[i].text
        # 챔피언 크롤링
        # sc-1xwhuw1-0 afFmu sc-1hmh1k6-4 dIKnaT
        champion =html.select('div.sc-1xwhuw1-0 img')[i*11]['alt']
        # 킬 관여율 크롤링
        kill_pati = html.select('span.sc-1p49g2y-1')[i*3].text[-5:-1]
        # 두번째 방법
        # your.gg의 게임 결과의 우측에 닉네임이 존재하는 순서를 통해 포지션 크롤링 하기
        # d490eh-10 dkiApC
        users = []
        for j in html.select('ul.d490eh-10 a'):
            users.append(j.text)
        if users[10*i:10*(i+1)].index(ingame_id) == 0 or users[10*i:10*(i+1)].index(ingame_id) == 1:
            position = 'top'
        elif users[10*i:10*(i+1)].index(ingame_id) == 2 or users[10*i:10*(i+1)].index(ingame_id) == 3:
            position = 'jungle'
        elif users[10*i:10*(i+1)].index(ingame_id) == 4 or users[10*i:10*(i+1)].index(ingame_id) == 5:
            position = 'mid'
        elif users[10*i:10*(i+1)].index(ingame_id) == 6 or users[10*i:10*(i+1)].index(ingame_id) == 7:
            position = 'adc'
        else:
            position = 'support'
        print(user_name,i+1, position)
        # 0~1 top
        # 2~3 jungle
        # 4~5 mid
        # 6~7 adc
        # 8~9 support
        data.append([ ingame_id, tier, Win_lose, champion, position, kill, death, assist, kill_pati ])

# %%
for i in df['nickname'][0:500]:
    #딜레이    
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(1) + round(np.random.random(),2)
    try :
        data_crawling(i)
    except:
        pass
# Out:
# 턱돼지 1 jungle
# 턱돼지 2 jungle
# 턱돼지 3 jungle
# 턱돼지 4 jungle
# 턱돼지 5 jungle
# 턱돼지 6 jungle
# 턱돼지 7 adc
# 턱돼지 8 top
# 턱돼지 9 top
# 턱돼지 10 jungle
# 턱돼지 11 adc
# 턱돼지 12 top
# 턱돼지 13 mid
# 턱돼지 14 mid
# 턱돼지 15 support
# 턱돼지 16 jungle
# 턱돼지 17 support
# 턱돼지 18 mid
# 턱돼지 19 adc
# 턱돼지 20 support
# 턱돼지 21 mid
# 턱돼지 22 support
# 턱돼지 23 jungle
# 턱돼지 24 jungle
# 턱돼지 25 adc
# 턱돼지 26 top
# 턱돼지 27 jungle
# 턱돼지 28 top
# 턱돼지 29 top
# 턱돼지 30 adc
# 핑찍으면우물잠수 1 top
# 핑찍으면우물잠수 2 top
# 핑찍으면우물잠수 3 top
# 핑찍으면우물잠수 4 top
# 핑찍으면우물잠수 5 top
# 핑찍으면우물잠수 6 top
# 핑찍으면우물잠수 7 top
# 핑찍으면우물잠수 8 top
# 핑찍으면우물잠수 9 top
# 핑찍으면우물잠수 10 top
# 핑찍으면우물잠수 11 top
# 핑찍으면우물잠수 12 top
# 핑찍으면우물잠수 13 top
# 핑찍으면우물잠수 14 support
# 핑찍으면우물잠수 15 top
# 핑찍으면우물잠수 16 top
# 핑찍으면우물잠수 17 support
# 핑찍으면우물잠수 18 mid
# 핑찍으면우물잠수 19 top
# 핑찍으면우물잠수 20 top
# 핑찍으면우물잠수 21 jungle
# 핑찍으면우물잠수 22 support
# 핑찍으면우물잠수 23 mid
# 핑찍으면우물잠수 24 top
# 핑찍으면우물잠수 25 top
# 핑찍으면우물잠수 26 top
# 핑찍으면우물잠수 27 top
# 핑찍으면우물잠수 28 top
# 핑찍으면우물잠수 29 top
# 핑찍으면우물잠수 30 top
# Visual Jockey 1 adc
# Visual Jockey 2 adc
# Visual Jockey 3 adc
# Visual Jockey 4 top
# Visual Jockey 5 adc
# Visual Jockey 6 adc
# Visual Jockey 7 jungle
# Visual Jockey 8 adc
# Visual Jockey 9 adc
# Visual Jockey 10 adc
# Visual Jockey 11 mid
# Visual Jockey 12 top
# Visual Jockey 13 mid
# Visual Jockey 14 jungle
# Visual Jockey 15 adc
# Visual Jockey 16 support
# Visual Jockey 17 mid
# Visual Jockey 18 top
# Visual Jockey 19 jungle
# Visual Jockey 20 top
# Visual Jockey 21 jungle
# Visual Jockey 22 adc
# Visual Jockey 23 adc
# Visual Jockey 24 adc
# Visual Jockey 25 top
# Visual Jockey 26 adc
# Visual Jockey 27 mid
# Visual Jockey 28 adc
# Visual Jockey 29 top
# Visual Jockey 30 top
# 이원일 1 adc
# 이원일 2 jungle
# 이원일 3 adc
# 이원일 4 mid
# 이원일 5 mid
# 이원일 6 top
# 이원일 7 top
# 이원일 8 jungle
# 이원일 9 adc
# 이원일 10 top
# 이원일 11 jungle
# 이원일 12 top
# 이원일 13 top
# 이원일 14 top
# 이원일 15 adc
# 이원일 16 adc
# 이원일 17 adc
# 이원일 18 mid
# 이원일 19 jungle
# 이원일 20 support
# 이원일 21 adc
# 이원일 22 jungle
# 이원일 23 jungle
# 이원일 24 adc
# 이원일 25 top
# 이원일 26 jungle
# 이원일 27 jungle
# 이원일 28 top
# 이원일 29 jungle
# 이원일 30 adc
# mvp맨 1 jungle
# mvp맨 2 jungle
# mvp맨 3 jungle
# mvp맨 4 jungle
# mvp맨 5 jungle
# mvp맨 6 jungle
# mvp맨 7 jungle
# mvp맨 8 jungle
# mvp맨 9 jungle
# mvp맨 10 jungle
# mvp맨 11 adc
# mvp맨 12 jungle
# mvp맨 13 jungle
# mvp맨 14 jungle
# mvp맨 15 jungle
# mvp맨 16 jungle
# mvp맨 17 support
# mvp맨 18 adc
# mvp맨 19 support
# mvp맨 20 jungle
# mvp맨 21 jungle
# mvp맨 22 adc
# mvp맨 23 jungle
# mvp맨 24 jungle
# mvp맨 25 jungle
# mvp맨 26 jungle
# mvp맨 27 adc
# mvp맨 28 adc
# mvp맨 29 top
# mvp맨 30 top
# 갱스터는살아있다 1 adc
# 갱스터는살아있다 2 top
# 갱스터는살아있다 3 adc
# 갱스터는살아있다 4 top
# 갱스터는살아있다 5 adc
# 갱스터는살아있다 6 adc
# 갱스터는살아있다 7 adc
# 갱스터는살아있다 8 adc
# 갱스터는살아있다 9 adc
# 갱스터는살아있다 10 jungle
# 갱스터는살아있다 11 adc
# 갱스터는살아있다 12 adc
# 갱스터는살아있다 13 adc
# 갱스터는살아있다 14 adc
# 갱스터는살아있다 15 top
# 갱스터는살아있다 16 adc
# 갱스터는살아있다 17 adc
# 갱스터는살아있다 18 adc
# 갱스터는살아있다 19 adc
# 갱스터는살아있다 20 top
# 갱스터는살아있다 21 adc
# 갱스터는살아있다 22 adc
# 갱스터는살아있다 23 jungle
# 갱스터는살아있다 24 adc
# 갱스터는살아있다 25 adc
# 갱스터는살아있다 26 adc
# 갱스터는살아있다 27 top
# 갱스터는살아있다 28 top
# 갱스터는살아있다 29 mid
# 갱스터는살아있다 30 adc
# 유하님 1 mid
# 유하님 2 adc
# 유하님 3 support
# 유하님 4 mid
# 유하님 5 mid
# 유하님 6 mid
# 유하님 7 mid
# 유하님 8 mid
# 유하님 9 mid
# 유하님 10 adc
# 유하님 11 mid
# 유하님 12 mid
# 유하님 13 jungle
# 유하님 14 mid
# 유하님 15 top
# 유하님 16 support
# 유하님 17 adc
# 유하님 18 jungle
# 유하님 19 jungle
# 유하님 20 support
# 유하님 21 top
# 유하님 22 adc
# 유하님 23 jungle
# 유하님 24 adc
# 유하님 25 top
# 유하님 26 mid
# 유하님 27 support
# 유하님 28 adc
# 유하님 29 support
# 유하님 30 mid
# 변태싸이코똘아이 1 jungle
# 변태싸이코똘아이 2 top
# 변태싸이코똘아이 3 jungle
# 변태싸이코똘아이 4 mid
# 변태싸이코똘아이 5 top
# 변태싸이코똘아이 6 top
# 변태싸이코똘아이 7 top
# 변태싸이코똘아이 8 mid
# 변태싸이코똘아이 9 mid
# 변태싸이코똘아이 10 jungle
# 변태싸이코똘아이 11 mid
# 변태싸이코똘아이 12 mid
# 변태싸이코똘아이 13 adc
# 변태싸이코똘아이 14 jungle
# 변태싸이코똘아이 15 support
# 변태싸이코똘아이 16 top
# 변태싸이코똘아이 17 top
# 변태싸이코똘아이 18 jungle
# 변태싸이코똘아이 19 top
# 변태싸이코똘아이 20 adc
# 변태싸이코똘아이 21 support
# 변태싸이코똘아이 22 support
# 변태싸이코똘아이 23 jungle
# 변태싸이코똘아이 24 mid
# 변태싸이코똘아이 25 mid
# 변태싸이코똘아이 26 support
# 변태싸이코똘아이 27 support
# 변태싸이코똘아이 28 adc
# 변태싸이코똘아이 29 jungle
# 변태싸이코똘아이 30 adc
# 4Cushion 1 jungle
# 4Cushion 2 jungle
# 4Cushion 3 top
# 4Cushion 4 mid
# 4Cushion 5 mid
# 4Cushion 6 jungle
# 4Cushion 7 jungle
# 4Cushion 8 top
# 4Cushion 9 top
# 4Cushion 10 support
# 4Cushion 11 jungle
# 4Cushion 12 jungle
# 4Cushion 13 jungle
# 4Cushion 14 jungle
# 4Cushion 15 jungle
# 4Cushion 16 jungle
# 4Cushion 17 jungle
# 4Cushion 18 jungle
# 4Cushion 19 jungle
# 4Cushion 20 jungle
# 4Cushion 21 jungle
# 4Cushion 22 jungle
# 4Cushion 23 jungle
# 4Cushion 24 jungle
# 4Cushion 25 jungle
# 4Cushion 26 jungle
# 4Cushion 27 top
# 4Cushion 28 jungle
# 4Cushion 29 support
# 4Cushion 30 jungle
# stanley randolph 1 jungle
# stanley randolph 2 jungle
# stanley randolph 3 jungle
# stanley randolph 4 jungle
# stanley randolph 5 mid
# stanley randolph 6 jungle
# stanley randolph 7 mid
# stanley randolph 8 mid
# stanley randolph 9 mid
# stanley randolph 10 jungle
# stanley randolph 11 jungle
# stanley randolph 12 jungle
# stanley randolph 13 jungle
# stanley randolph 14 jungle
# stanley randolph 15 jungle
# stanley randolph 16 jungle
# stanley randolph 17 jungle
# stanley randolph 18 jungle
# stanley randolph 19 jungle
# stanley randolph 20 jungle
# stanley randolph 21 jungle
# stanley randolph 22 jungle
# stanley randolph 23 jungle
# stanley randolph 24 jungle
# stanley randolph 25 jungle
# stanley randolph 26 jungle
# stanley randolph 27 jungle
# stanley randolph 28 jungle
# stanley randolph 29 jungle
# stanley randolph 30 jungle
# 곽대호 1 adc
# 곽대호 2 adc
# 곽대호 3 adc
# 곽대호 4 mid
# 곽대호 5 mid
# 곽대호 6 mid
# 곽대호 7 adc
# 곽대호 8 adc
# 곽대호 9 top
# 곽대호 10 jungle
# 곽대호 11 mid
# 곽대호 12 top
# 곽대호 13 adc
# 곽대호 14 top
# 곽대호 15 support
# 곽대호 16 adc
# 곽대호 17 top
# 곽대호 18 support
# 곽대호 19 mid
# 곽대호 20 top
# 곽대호 21 top
# 곽대호 22 mid
# 곽대호 23 adc
# 곽대호 24 mid
# 곽대호 25 jungle
# 곽대호 26 adc
# 곽대호 27 support
# 곽대호 28 top
# 곽대호 29 adc
# 곽대호 30 mid
# SHAKO SMOKE 1 adc
# SHAKO SMOKE 2 adc
# SHAKO SMOKE 3 adc
# SHAKO SMOKE 4 jungle
# SHAKO SMOKE 5 top
# SHAKO SMOKE 6 top
# SHAKO SMOKE 7 top
# SHAKO SMOKE 8 adc
# SHAKO SMOKE 9 jungle
# SHAKO SMOKE 10 mid
# SHAKO SMOKE 11 mid
# SHAKO SMOKE 12 mid
# SHAKO SMOKE 13 mid
# SHAKO SMOKE 14 jungle
# SHAKO SMOKE 15 support
# SHAKO SMOKE 16 jungle
# SHAKO SMOKE 17 mid
# SHAKO SMOKE 18 mid
# SHAKO SMOKE 19 top
# SHAKO SMOKE 20 top
# SHAKO SMOKE 21 top
# SHAKO SMOKE 22 support
# SHAKO SMOKE 23 jungle
# SHAKO SMOKE 24 jungle
# SHAKO SMOKE 25 jungle
# SHAKO SMOKE 26 jungle
# SHAKO SMOKE 27 top
# SHAKO SMOKE 28 mid
# SHAKO SMOKE 29 support
# SHAKO SMOKE 30 top
# 지건을배운먀옹이 1 support
# 지건을배운먀옹이 2 support
# 지건을배운먀옹이 3 support
# 지건을배운먀옹이 4 support
# 지건을배운먀옹이 5 mid
# 지건을배운먀옹이 6 support
# 지건을배운먀옹이 7 support
# 지건을배운먀옹이 8 support
# 지건을배운먀옹이 9 support
# 지건을배운먀옹이 10 support
# 지건을배운먀옹이 11 support
# 지건을배운먀옹이 12 support
# 지건을배운먀옹이 13 jungle
# 지건을배운먀옹이 14 support
# 지건을배운먀옹이 15 mid
# 지건을배운먀옹이 16 jungle
# 지건을배운먀옹이 17 jungle
# 지건을배운먀옹이 18 support
# 지건을배운먀옹이 19 support
# 지건을배운먀옹이 20 support
# 지건을배운먀옹이 21 mid
# 지건을배운먀옹이 22 mid
# 지건을배운먀옹이 23 mid
# 지건을배운먀옹이 24 mid
# 지건을배운먀옹이 25 adc
# 지건을배운먀옹이 26 adc
# 지건을배운먀옹이 27 mid
# 지건을배운먀옹이 28 mid
# 지건을배운먀옹이 29 mid
# 지건을배운먀옹이 30 adc
# 부산할매선지국밥 1 top
# 부산할매선지국밥 2 top
# 부산할매선지국밥 3 mid
# 부산할매선지국밥 4 top
# 부산할매선지국밥 5 jungle
# 부산할매선지국밥 6 adc
# 부산할매선지국밥 7 mid
# 부산할매선지국밥 8 jungle
# 부산할매선지국밥 9 jungle
# 부산할매선지국밥 10 jungle
# 부산할매선지국밥 11 jungle
# 부산할매선지국밥 12 jungle
# 부산할매선지국밥 13 jungle
# 부산할매선지국밥 14 jungle
# 부산할매선지국밥 15 jungle
# 부산할매선지국밥 16 jungle
# 부산할매선지국밥 17 mid
# 부산할매선지국밥 18 top
# 부산할매선지국밥 19 mid
# 부산할매선지국밥 20 top
# 부산할매선지국밥 21 top
# 부산할매선지국밥 22 adc
# 부산할매선지국밥 23 top
# 부산할매선지국밥 24 jungle
# 부산할매선지국밥 25 adc
# 부산할매선지국밥 26 jungle
# 부산할매선지국밥 27 mid
# 부산할매선지국밥 28 adc
# 부산할매선지국밥 29 support
# 부산할매선지국밥 30 support
# GamerG90 1 support
# GamerG90 2 top
# GamerG90 3 adc
# GamerG90 4 jungle
# GamerG90 5 support
# GamerG90 6 mid
# GamerG90 7 adc
# GamerG90 8 support
# GamerG90 9 support
# GamerG90 10 adc
# GamerG90 11 top
# GamerG90 12 support
# GamerG90 13 top
# GamerG90 14 adc
# GamerG90 15 top
# GamerG90 16 support
# GamerG90 17 top
# GamerG90 18 support
# GamerG90 19 top
# GamerG90 20 top
# GamerG90 21 support
# GamerG90 22 mid
# GamerG90 23 jungle
# GamerG90 24 top
# GamerG90 25 top
# GamerG90 26 support
# GamerG90 27 top
# GamerG90 28 top
# GamerG90 29 support
# GamerG90 30 support
# 공격수셰프 1 top
# 공격수셰프 2 top
# 공격수셰프 3 top
# 공격수셰프 4 top
# 공격수셰프 5 top
# 공격수셰프 6 top
# 공격수셰프 7 top
# 공격수셰프 8 top
# 공격수셰프 9 top
# 공격수셰프 10 top
# 공격수셰프 11 top
# 공격수셰프 12 top
# 공격수셰프 13 top
# 공격수셰프 14 top
# 공격수셰프 15 top
# 공격수셰프 16 top
# 공격수셰프 17 top
# 공격수셰프 18 top
# 공격수셰프 19 support
# 공격수셰프 20 top
# 공격수셰프 21 top
# 공격수셰프 22 top
# 공격수셰프 23 top
# 공격수셰프 24 top
# 공격수셰프 25 jungle
# 공격수셰프 26 jungle
# 공격수셰프 27 support
# 공격수셰프 28 top
# 공격수셰프 29 top
# 공격수셰프 30 top
# LAON아띠 1 top
# LAON아띠 2 jungle
# LAON아띠 3 adc
# LAON아띠 4 adc
# LAON아띠 5 jungle
# LAON아띠 6 top
# LAON아띠 7 adc
# LAON아띠 8 adc
# LAON아띠 9 adc
# LAON아띠 10 top
# LAON아띠 11 mid
# LAON아띠 12 top
# LAON아띠 13 top
# LAON아띠 14 top
# LAON아띠 15 top
# LAON아띠 16 adc
# LAON아띠 17 mid
# LAON아띠 18 jungle
# LAON아띠 19 adc
# LAON아띠 20 jungle
# LAON아띠 21 adc
# LAON아띠 22 adc
# LAON아띠 23 top
# LAON아띠 24 adc
# LAON아띠 25 mid
# LAON아띠 26 mid
# LAON아띠 27 top
# LAON아띠 28 mid
# LAON아띠 29 adc
# LAON아띠 30 mid
# 은톨이 1 jungle
# 은톨이 2 support
# 은톨이 3 support
# 은톨이 4 jungle
# 은톨이 5 mid
# 은톨이 6 jungle
# 은톨이 7 jungle
# 은톨이 8 jungle
# 은톨이 9 adc
# 은톨이 10 adc
# 은톨이 11 jungle
# 은톨이 12 support
# 은톨이 13 top
# 은톨이 14 top
# 은톨이 15 top
# 은톨이 16 support
# 은톨이 17 adc
# 은톨이 18 top
# 은톨이 19 mid
# 은톨이 20 top
# 은톨이 21 support
# 은톨이 22 support
# 은톨이 23 support
# 은톨이 24 support
# 은톨이 25 support
# 은톨이 26 support
# 은톨이 27 support
# 은톨이 28 support
# 은톨이 29 support
# 은톨이 30 support
# 킨드럐드 1 mid
# 킨드럐드 2 mid
# 킨드럐드 3 jungle
# 킨드럐드 4 top
# 킨드럐드 5 jungle
# 킨드럐드 6 mid
# 킨드럐드 7 top
# 킨드럐드 8 top
# 킨드럐드 9 jungle
# 킨드럐드 10 top
# 킨드럐드 11 jungle
# 킨드럐드 12 jungle
# 킨드럐드 13 top
# 킨드럐드 14 top
# 킨드럐드 15 top
# 킨드럐드 16 jungle
# 킨드럐드 17 top
# 킨드럐드 18 jungle
# 킨드럐드 19 mid
# 킨드럐드 20 mid
# 킨드럐드 21 top
# 킨드럐드 22 top
# 킨드럐드 23 mid
# 킨드럐드 24 adc
# 킨드럐드 25 top
# 킨드럐드 26 top
# 킨드럐드 27 jungle
# 킨드럐드 28 mid
# 킨드럐드 29 mid
# 킨드럐드 30 mid
# 리리멍 1 support
# 리리멍 2 support
# 리리멍 3 jungle
# 리리멍 4 adc
# 리리멍 5 top
# 리리멍 6 mid
# 리리멍 7 adc
# 리리멍 8 support
# 리리멍 9 support
# 리리멍 10 adc
# 리리멍 11 top
# 리리멍 12 mid
# 리리멍 13 jungle
# 리리멍 14 jungle
# 리리멍 15 jungle
# 리리멍 16 mid
# 리리멍 17 top
# 리리멍 18 support
# 리리멍 19 mid
# 리리멍 20 top
# 리리멍 21 top
# 리리멍 22 mid
# 리리멍 23 support
# 리리멍 24 top
# 리리멍 25 support
# 리리멍 26 support
# 리리멍 27 mid
# 리리멍 28 mid
# 리리멍 29 mid
# 리리멍 30 support
# 솔킬따면너네이김 1 support
# 솔킬따면너네이김 2 support
# 솔킬따면너네이김 3 support
# 솔킬따면너네이김 4 support
# 솔킬따면너네이김 5 mid
# 솔킬따면너네이김 6 mid
# 솔킬따면너네이김 7 mid
# 솔킬따면너네이김 8 support
# 솔킬따면너네이김 9 mid
# 솔킬따면너네이김 10 mid
# 솔킬따면너네이김 11 mid
# 솔킬따면너네이김 12 mid
# 솔킬따면너네이김 13 mid
# 솔킬따면너네이김 14 mid
# 솔킬따면너네이김 15 mid
# 솔킬따면너네이김 16 mid
# 솔킬따면너네이김 17 mid
# 솔킬따면너네이김 18 mid
# 솔킬따면너네이김 19 mid
# 솔킬따면너네이김 20 mid
# 솔킬따면너네이김 21 mid
# 솔킬따면너네이김 22 mid
# 솔킬따면너네이김 23 mid
# 솔킬따면너네이김 24 mid
# 솔킬따면너네이김 25 mid
# 솔킬따면너네이김 26 mid
# 솔킬따면너네이김 27 top
# 솔킬따면너네이김 28 mid
# 솔킬따면너네이김 29 mid
# 솔킬따면너네이김 30 mid
# 극딜엔빨간약 1 support
# 극딜엔빨간약 2 jungle
# 극딜엔빨간약 3 jungle
# 극딜엔빨간약 4 jungle
# 극딜엔빨간약 5 jungle
# 극딜엔빨간약 6 jungle
# 극딜엔빨간약 7 jungle
# 극딜엔빨간약 8 jungle
# 극딜엔빨간약 9 jungle
# 극딜엔빨간약 10 jungle
# 극딜엔빨간약 11 jungle
# 극딜엔빨간약 12 top
# 극딜엔빨간약 13 jungle
# 극딜엔빨간약 14 jungle
# 극딜엔빨간약 15 adc
# 극딜엔빨간약 16 adc
# 극딜엔빨간약 17 adc
# 극딜엔빨간약 18 adc
# 극딜엔빨간약 19 adc
# 극딜엔빨간약 20 adc
# 극딜엔빨간약 21 adc
# 극딜엔빨간약 22 adc
# 극딜엔빨간약 23 top
# 극딜엔빨간약 24 support
# 극딜엔빨간약 25 adc
# 극딜엔빨간약 26 adc
# 극딜엔빨간약 27 adc
# 극딜엔빨간약 28 adc
# 극딜엔빨간약 29 jungle
# 극딜엔빨간약 30 adc
# 땡보 1 top
# 땡보 2 mid
# 땡보 3 jungle
# 땡보 4 jungle
# 땡보 5 jungle
# 땡보 6 jungle
# 땡보 7 jungle
# 땡보 8 jungle
# 땡보 9 jungle
# 땡보 10 jungle
# 땡보 11 jungle
# 땡보 12 jungle
# 땡보 13 jungle
# 땡보 14 jungle
# 땡보 15 jungle
# 땡보 16 jungle
# 땡보 17 jungle
# 땡보 18 jungle
# 땡보 19 top
# 땡보 20 jungle
# 땡보 21 adc
# 땡보 22 support
# 땡보 23 support
# 땡보 24 mid
# 땡보 25 jungle
# 땡보 26 support
# 땡보 27 top
# 땡보 28 mid
# 땡보 29 mid
# 땡보 30 support
# Amaranth 1 mid
# Amaranth 2 mid
# Amaranth 3 support
# Amaranth 4 support
# Amaranth 5 support
# Amaranth 6 support
# Amaranth 7 support
# Amaranth 8 adc
# Amaranth 9 support
# Amaranth 10 jungle
# Amaranth 11 adc
# Amaranth 12 mid
# Amaranth 13 mid
# Amaranth 14 mid
# Amaranth 15 top
# Amaranth 16 jungle
# Amaranth 17 mid
# Amaranth 18 jungle
# Amaranth 19 mid
# Amaranth 20 top
# Amaranth 21 top
# Amaranth 22 jungle
# Amaranth 23 top
# Amaranth 24 adc
# Amaranth 25 support
# Amaranth 26 support
# Amaranth 27 mid
# Amaranth 28 mid
# Amaranth 29 mid
# Amaranth 30 top
# 반용용 1 jungle
# 반용용 2 adc
# 반용용 3 adc
# 반용용 4 support
# 반용용 5 jungle
# 반용용 6 jungle
# 반용용 7 adc
# 반용용 8 top
# 반용용 9 jungle
# 반용용 10 top
# 반용용 11 adc
# 반용용 12 adc
# 반용용 13 top
# 반용용 14 mid
# 반용용 15 jungle
# 반용용 16 jungle
# 반용용 17 jungle
# 반용용 18 support
# 반용용 19 support
# 반용용 20 support
# 반용용 21 jungle
# 반용용 22 support
# 반용용 23 mid
# 반용용 24 support
# 반용용 25 mid
# 반용용 26 top
# 반용용 27 support
# 반용용 28 jungle
# 반용용 29 mid
# 반용용 30 support
# 내고추한라산 1 mid
# 내고추한라산 2 jungle
# 내고추한라산 3 support
# 내고추한라산 4 jungle
# 내고추한라산 5 adc
# 내고추한라산 6 adc
# 내고추한라산 7 adc
# 내고추한라산 8 support
# 내고추한라산 9 adc
# 내고추한라산 10 jungle
# 내고추한라산 11 adc
# 내고추한라산 12 jungle
# 내고추한라산 13 jungle
# 내고추한라산 14 top
# 내고추한라산 15 mid
# 내고추한라산 16 top
# 내고추한라산 17 adc
# 내고추한라산 18 jungle
# 내고추한라산 19 top
# 내고추한라산 20 adc
# 내고추한라산 21 top
# 내고추한라산 22 adc
# 내고추한라산 23 adc
# 내고추한라산 24 top
# 내고추한라산 25 top
# 내고추한라산 26 adc
# 내고추한라산 27 mid
# 내고추한라산 28 mid
# 조밥ol 1 adc
# 조밥ol 2 adc
# 조밥ol 3 adc
# 조밥ol 4 adc
# 조밥ol 5 adc
# 조밥ol 6 adc
# 조밥ol 7 adc
# 조밥ol 8 adc
# 조밥ol 9 adc
# 조밥ol 10 adc
# 조밥ol 11 adc
# 조밥ol 12 adc
# 조밥ol 13 adc
# 조밥ol 14 adc
# 조밥ol 15 adc
# 조밥ol 16 adc
# 조밥ol 17 adc
# 조밥ol 18 adc
# 조밥ol 19 adc
# 조밥ol 20 adc
# 조밥ol 21 adc
# 조밥ol 22 adc
# 조밥ol 23 adc
# 조밥ol 24 adc
# 조밥ol 25 adc
# 조밥ol 26 adc
# 조밥ol 27 adc
# 조밥ol 28 adc
# 조밥ol 29 adc
# 조밥ol 30 adc
# 으아이양 1 support
# 으아이양 2 support
# 으아이양 3 jungle
# 으아이양 4 support
# 으아이양 5 adc
# 으아이양 6 adc
# 으아이양 7 jungle
# 으아이양 8 mid
# 으아이양 9 top
# 으아이양 10 mid
# 으아이양 11 top
# 으아이양 12 adc
# 으아이양 13 mid
# 으아이양 14 mid
# 으아이양 15 support
# 으아이양 16 support
# 으아이양 17 top
# 으아이양 18 mid
# 으아이양 19 mid
# 으아이양 20 top
# 으아이양 21 support
# 으아이양 22 top
# 으아이양 23 adc
# 으아이양 24 mid
# 으아이양 25 support
# 으아이양 26 adc
# 으아이양 27 mid
# 으아이양 28 adc
# 으아이양 29 support
# 으아이양 30 adc
# C드라이브 1 mid
# C드라이브 2 support
# C드라이브 3 adc
# C드라이브 4 mid
# C드라이브 5 top
# C드라이브 6 top
# C드라이브 7 jungle
# C드라이브 8 adc
# C드라이브 9 adc
# C드라이브 10 adc
# C드라이브 11 support
# C드라이브 12 mid
# C드라이브 13 mid
# C드라이브 14 top
# C드라이브 15 jungle
# C드라이브 16 support
# C드라이브 17 support
# C드라이브 18 support
# C드라이브 19 support
# C드라이브 20 adc
# C드라이브 21 jungle
# C드라이브 22 jungle
# C드라이브 23 adc
# C드라이브 24 jungle
# C드라이브 25 jungle
# C드라이브 26 mid
# 바위게맨 1 mid
# 바위게맨 2 adc
# 바위게맨 3 top
# 바위게맨 4 jungle
# 바위게맨 5 mid
# 바위게맨 6 jungle
# 바위게맨 7 jungle
# 바위게맨 8 adc
# 바위게맨 9 jungle
# 바위게맨 10 jungle
# 바위게맨 11 jungle
# 바위게맨 12 jungle
# 바위게맨 13 adc
# 바위게맨 14 jungle
# 바위게맨 15 jungle
# 바위게맨 16 jungle
# 바위게맨 17 jungle
# 바위게맨 18 jungle
# 바위게맨 19 jungle
# 바위게맨 20 jungle
# 바위게맨 21 jungle
# 바위게맨 22 jungle
# 바위게맨 23 support
# 바위게맨 24 jungle
# 바위게맨 25 jungle
# 바위게맨 26 jungle
# 바위게맨 27 support
# 바위게맨 28 jungle
# 바위게맨 29 jungle
# 바위게맨 30 jungle
# 마스터이 1 jungle
# 마스터이 2 mid
# 마스터이 3 jungle
# 마스터이 4 jungle
# 마스터이 5 mid
# 마스터이 6 mid
# 마스터이 7 mid
# 마스터이 8 jungle
# 마스터이 9 mid
# 마스터이 10 jungle
# 마스터이 11 jungle
# 마스터이 12 jungle
# 마스터이 13 mid
# 마스터이 14 jungle
# 마스터이 15 jungle
# 마스터이 16 jungle
# 마스터이 17 jungle
# 마스터이 18 mid
# 마스터이 19 jungle
# 마스터이 20 jungle
# 마스터이 21 jungle
# 마스터이 22 jungle
# 마스터이 23 mid
# 마스터이 24 mid
# 마스터이 25 mid
# 마스터이 26 mid
# 마스터이 27 jungle
# 마스터이 28 mid
# 마스터이 29 mid
# 척화 1 support
# 척화 2 support
# 척화 3 top
# 척화 4 mid
# 척화 5 top
# 척화 6 top
# 척화 7 top
# 척화 8 top
# 척화 9 support
# 척화 10 support
# 척화 11 support
# 척화 12 support
# 척화 13 support
# 척화 14 top
# 척화 15 adc
# 척화 16 jungle
# 척화 17 top
# 척화 18 top
# 척화 19 top
# 척화 20 top
# 척화 21 top
# 척화 22 top
# 척화 23 top
# 척화 24 adc
# 척화 25 top
# 척화 26 support
# 척화 27 support
# 척화 28 top
# 척화 29 mid
# 척화 30 adc
# 똥받아줘 1 jungle
# 똥받아줘 2 adc
# 똥받아줘 3 adc
# 똥받아줘 4 jungle
# 똥받아줘 5 support
# 똥받아줘 6 top
# 똥받아줘 7 jungle
# 똥받아줘 8 top
# 똥받아줘 9 support
# 똥받아줘 10 support
# 똥받아줘 11 adc
# 똥받아줘 12 top
# 똥받아줘 13 top
# 똥받아줘 14 top
# 똥받아줘 15 top
# 똥받아줘 16 top
# 똥받아줘 17 adc
# 똥받아줘 18 support
# 똥받아줘 19 adc
# 똥받아줘 20 adc
# 똥받아줘 21 top
# 똥받아줘 22 top
# 똥받아줘 23 top
# 똥받아줘 24 top
# 똥받아줘 25 top
# 똥받아줘 26 top
# 똥받아줘 27 jungle
# 똥받아줘 28 support
# 똥받아줘 29 mid
# 똥받아줘 30 jungle
# kimchi맨 1 jungle
# kimchi맨 2 jungle
# kimchi맨 3 jungle
# kimchi맨 4 jungle
# kimchi맨 5 jungle
# kimchi맨 6 jungle
# kimchi맨 7 support
# kimchi맨 8 jungle
# kimchi맨 9 jungle
# kimchi맨 10 jungle
# kimchi맨 11 jungle
# kimchi맨 12 jungle
# kimchi맨 13 jungle
# kimchi맨 14 support
# kimchi맨 15 top
# kimchi맨 16 top
# kimchi맨 17 top
# kimchi맨 18 top
# kimchi맨 19 top
# kimchi맨 20 top
# kimchi맨 21 top
# kimchi맨 22 top
# kimchi맨 23 top
# kimchi맨 24 top
# kimchi맨 25 top
# kimchi맨 26 top
# kimchi맨 27 top
# kimchi맨 28 jungle
# 정상수의정상위썰 1 mid
# 정상수의정상위썰 2 mid
# 정상수의정상위썰 3 adc
# 정상수의정상위썰 4 adc
# 정상수의정상위썰 5 adc
# 정상수의정상위썰 6 adc
# 정상수의정상위썰 7 top
# 정상수의정상위썰 8 adc
# 정상수의정상위썰 9 adc
# 정상수의정상위썰 10 adc
# 정상수의정상위썰 11 adc
# 정상수의정상위썰 12 mid
# 정상수의정상위썰 13 mid
# 정상수의정상위썰 14 mid
# 정상수의정상위썰 15 adc
# 정상수의정상위썰 16 adc
# 정상수의정상위썰 17 top
# 정상수의정상위썰 18 adc
# 정상수의정상위썰 19 adc
# 정상수의정상위썰 20 mid
# 정상수의정상위썰 21 mid
# 정상수의정상위썰 22 mid
# 정상수의정상위썰 23 mid
# 정상수의정상위썰 24 top
# 정상수의정상위썰 25 adc
# 정상수의정상위썰 26 adc
# 정상수의정상위썰 27 adc
# 정상수의정상위썰 28 mid
# 정상수의정상위썰 29 mid
# 정상수의정상위썰 30 mid
# 뜩뚜기 1 mid
# 뜩뚜기 2 mid
# 뜩뚜기 3 adc
# 뜩뚜기 4 adc
# 뜩뚜기 5 mid
# 뜩뚜기 6 mid
# 뜩뚜기 7 support
# 뜩뚜기 8 support
# 뜩뚜기 9 support
# 뜩뚜기 10 adc
# 뜩뚜기 11 adc
# 뜩뚜기 12 support
# 뜩뚜기 13 mid
# 뜩뚜기 14 mid
# 뜩뚜기 15 mid
# 뜩뚜기 16 mid
# 뜩뚜기 17 adc
# 뜩뚜기 18 mid
# 뜩뚜기 19 support
# 뜩뚜기 20 support
# 뜩뚜기 21 support
# 뜩뚜기 22 adc
# 뜩뚜기 23 mid
# 뜩뚜기 24 support
# 뜩뚜기 25 support
# 뜩뚜기 26 support
# 뜩뚜기 27 adc
# 뜩뚜기 28 adc
# 뜩뚜기 29 mid
# 뜩뚜기 30 mid
# 예삐랑꿀이 1 top
# 예삐랑꿀이 2 top
# 예삐랑꿀이 3 jungle
# 예삐랑꿀이 4 jungle
# 예삐랑꿀이 5 jungle
# 예삐랑꿀이 6 jungle
# 예삐랑꿀이 7 jungle
# 예삐랑꿀이 8 jungle
# 예삐랑꿀이 9 jungle
# 예삐랑꿀이 10 jungle
# 예삐랑꿀이 11 jungle
# 예삐랑꿀이 12 top
# 예삐랑꿀이 13 jungle
# 예삐랑꿀이 14 top
# 예삐랑꿀이 15 jungle
# 예삐랑꿀이 16 jungle
# 예삐랑꿀이 17 jungle
# 예삐랑꿀이 18 jungle
# 예삐랑꿀이 19 jungle
# 예삐랑꿀이 20 jungle
# 예삐랑꿀이 21 top
# 예삐랑꿀이 22 top
# 예삐랑꿀이 23 support
# 예삐랑꿀이 24 support
# 예삐랑꿀이 25 mid
# 예삐랑꿀이 26 mid
# 예삐랑꿀이 27 mid
# 예삐랑꿀이 28 mid
# 예삐랑꿀이 29 jungle
# 예삐랑꿀이 30 top
# Godog 1 top
# Godog 2 support
# Godog 3 adc
# Godog 4 jungle
# Godog 5 mid
# Godog 6 mid
# Godog 7 mid
# Godog 8 adc
# Godog 9 mid
# Godog 10 top
# Godog 11 top
# Godog 12 adc
# Godog 13 top
# Godog 14 jungle
# Godog 15 mid
# Godog 16 jungle
# Godog 17 support
# Godog 18 mid
# Godog 19 adc
# Godog 20 adc
# Godog 21 mid
# Godog 22 adc
# Godog 23 mid
# Godog 24 top
# Godog 25 jungle
# Godog 26 jungle
# Godog 27 jungle
# Godog 28 jungle
# Godog 29 support
# Godog 30 top
# KwonSiWoo 1 adc
# KwonSiWoo 2 mid
# KwonSiWoo 3 mid
# KwonSiWoo 4 support
# KwonSiWoo 5 mid
# KwonSiWoo 6 support
# KwonSiWoo 7 mid
# KwonSiWoo 8 mid
# KwonSiWoo 9 support
# KwonSiWoo 10 support
# KwonSiWoo 11 support
# KwonSiWoo 12 support
# KwonSiWoo 13 support
# KwonSiWoo 14 mid
# KwonSiWoo 15 jungle
# KwonSiWoo 16 top
# KwonSiWoo 17 top
# KwonSiWoo 18 support
# KwonSiWoo 19 top
# KwonSiWoo 20 jungle
# KwonSiWoo 21 support
# KwonSiWoo 22 top
# KwonSiWoo 23 mid
# KwonSiWoo 24 jungle
# KwonSiWoo 25 top
# KwonSiWoo 26 top
# KwonSiWoo 27 jungle
# KwonSiWoo 28 mid
# KwonSiWoo 29 support
# KwonSiWoo 30 support
# 조선인의안락사만이유일한구원 1 jungle
# 조선인의안락사만이유일한구원 2 jungle
# 조선인의안락사만이유일한구원 3 jungle
# 조선인의안락사만이유일한구원 4 jungle
# 조선인의안락사만이유일한구원 5 adc
# 조선인의안락사만이유일한구원 6 top
# 조선인의안락사만이유일한구원 7 jungle
# 조선인의안락사만이유일한구원 8 jungle
# 조선인의안락사만이유일한구원 9 top
# 조선인의안락사만이유일한구원 10 jungle
# 조선인의안락사만이유일한구원 11 support
# 조선인의안락사만이유일한구원 12 jungle
# 조선인의안락사만이유일한구원 13 jungle
# 조선인의안락사만이유일한구원 14 mid
# 조선인의안락사만이유일한구원 15 jungle
# 조선인의안락사만이유일한구원 16 jungle
# 조선인의안락사만이유일한구원 17 jungle
# 조선인의안락사만이유일한구원 18 support
# 조선인의안락사만이유일한구원 19 top
# 조선인의안락사만이유일한구원 20 support
# 조선인의안락사만이유일한구원 21 mid
# 조선인의안락사만이유일한구원 22 mid
# 조선인의안락사만이유일한구원 23 mid
# 조선인의안락사만이유일한구원 24 mid
# 조선인의안락사만이유일한구원 25 mid
# 조선인의안락사만이유일한구원 26 top
# 조선인의안락사만이유일한구원 27 adc
# 조선인의안락사만이유일한구원 28 jungle
# 조선인의안락사만이유일한구원 29 top
# 조선인의안락사만이유일한구원 30 support
# TakinMyHeart 1 top
# TakinMyHeart 2 top
# TakinMyHeart 3 support
# TakinMyHeart 4 support
# TakinMyHeart 5 top
# TakinMyHeart 6 top
# TakinMyHeart 7 top
# TakinMyHeart 8 top
# TakinMyHeart 9 top
# TakinMyHeart 10 top
# TakinMyHeart 11 support
# TakinMyHeart 12 top
# TakinMyHeart 13 top
# TakinMyHeart 14 top
# TakinMyHeart 15 mid
# TakinMyHeart 16 top
# TakinMyHeart 17 adc
# TakinMyHeart 18 top
# TakinMyHeart 19 top
# TakinMyHeart 20 support
# TakinMyHeart 21 support
# TakinMyHeart 22 support
# TakinMyHeart 23 support
# TakinMyHeart 24 mid
# TakinMyHeart 25 top
# TakinMyHeart 26 top
# TakinMyHeart 27 mid
# TakinMyHeart 28 mid
# TakinMyHeart 29 adc
# TakinMyHeart 30 top
# 북해도고양이유미 1 support
# 북해도고양이유미 2 support
# 북해도고양이유미 3 support
# 북해도고양이유미 4 jungle
# 북해도고양이유미 5 jungle
# 북해도고양이유미 6 jungle
# 북해도고양이유미 7 support
# 북해도고양이유미 8 support
# 북해도고양이유미 9 support
# 북해도고양이유미 10 support
# 북해도고양이유미 11 support
# 북해도고양이유미 12 support
# 북해도고양이유미 13 jungle
# 북해도고양이유미 14 support
# 북해도고양이유미 15 jungle
# 북해도고양이유미 16 support
# 북해도고양이유미 17 jungle
# 북해도고양이유미 18 support
# 북해도고양이유미 19 jungle
# 북해도고양이유미 20 jungle
# 북해도고양이유미 21 jungle
# 북해도고양이유미 22 support
# 북해도고양이유미 23 support
# 북해도고양이유미 24 jungle
# 북해도고양이유미 25 support
# 북해도고양이유미 26 support
# 북해도고양이유미 27 support
# 북해도고양이유미 28 support
# 북해도고양이유미 29 jungle
# 북해도고양이유미 30 jungle
# 안소니홉킨스 1 adc
# 안소니홉킨스 2 adc
# 안소니홉킨스 3 adc
# 안소니홉킨스 4 top
# 안소니홉킨스 5 support
# 안소니홉킨스 6 top
# 안소니홉킨스 7 support
# 안소니홉킨스 8 top
# 안소니홉킨스 9 top
# 안소니홉킨스 10 top
# 안소니홉킨스 11 adc
# 안소니홉킨스 12 support
# 안소니홉킨스 13 top
# 안소니홉킨스 14 top
# 안소니홉킨스 15 top
# 안소니홉킨스 16 top
# 안소니홉킨스 17 top
# 안소니홉킨스 18 support
# 안소니홉킨스 19 top
# 안소니홉킨스 20 support
# 안소니홉킨스 21 mid
# 안소니홉킨스 22 jungle
# 안소니홉킨스 23 support
# 안소니홉킨스 24 support
# 안소니홉킨스 25 adc
# 안소니홉킨스 26 adc
# 안소니홉킨스 27 support
# 안소니홉킨스 28 support
# 안소니홉킨스 29 support
# 안소니홉킨스 30 adc
# 꿇뚫꿇뚫꿇뚫 1 mid
# 꿇뚫꿇뚫꿇뚫 2 adc
# 꿇뚫꿇뚫꿇뚫 3 jungle
# 꿇뚫꿇뚫꿇뚫 4 adc
# 꿇뚫꿇뚫꿇뚫 5 mid
# 꿇뚫꿇뚫꿇뚫 6 adc
# 꿇뚫꿇뚫꿇뚫 7 jungle
# 꿇뚫꿇뚫꿇뚫 8 support
# 꿇뚫꿇뚫꿇뚫 9 mid
# 꿇뚫꿇뚫꿇뚫 10 jungle
# 꿇뚫꿇뚫꿇뚫 11 mid
# 꿇뚫꿇뚫꿇뚫 12 mid
# 꿇뚫꿇뚫꿇뚫 13 support
# 꿇뚫꿇뚫꿇뚫 14 support
# 꿇뚫꿇뚫꿇뚫 15 top
# 꿇뚫꿇뚫꿇뚫 16 mid
# 꿇뚫꿇뚫꿇뚫 17 adc
# 꿇뚫꿇뚫꿇뚫 18 support
# 꿇뚫꿇뚫꿇뚫 19 support
# 꿇뚫꿇뚫꿇뚫 20 jungle
# 꿇뚫꿇뚫꿇뚫 21 support
# 꿇뚫꿇뚫꿇뚫 22 top
# 꿇뚫꿇뚫꿇뚫 23 support
# 꿇뚫꿇뚫꿇뚫 24 support
# 꿇뚫꿇뚫꿇뚫 25 adc
# 꿇뚫꿇뚫꿇뚫 26 adc
# 꿇뚫꿇뚫꿇뚫 27 jungle
# 꿇뚫꿇뚫꿇뚫 28 jungle
# 꿇뚫꿇뚫꿇뚫 29 top
# 1월5일60억증발 1 mid
# 1월5일60억증발 2 mid
# 1월5일60억증발 3 adc
# 1월5일60억증발 4 adc
# 1월5일60억증발 5 adc
# 1월5일60억증발 6 adc
# 1월5일60억증발 7 mid
# 1월5일60억증발 8 mid
# 1월5일60억증발 9 mid
# 1월5일60억증발 10 support
# 1월5일60억증발 11 support
# 1월5일60억증발 12 support
# 1월5일60억증발 13 support
# 1월5일60억증발 14 support
# 1월5일60억증발 15 support
# 1월5일60억증발 16 support
# 1월5일60억증발 17 support
# 1월5일60억증발 18 support
# 1월5일60억증발 19 adc
# 1월5일60억증발 20 adc
# 1월5일60억증발 21 adc
# 1월5일60억증발 22 mid
# 1월5일60억증발 23 top
# 1월5일60억증발 24 adc
# 1월5일60억증발 25 top
# 1월5일60억증발 26 adc
# 1월5일60억증발 27 adc
# 1월5일60억증발 28 adc
# 1월5일60억증발 29 adc
# 1월5일60억증발 30 adc
# 그아가리좀닥쳐 1 top
# 그아가리좀닥쳐 2 jungle
# 그아가리좀닥쳐 3 jungle
# 그아가리좀닥쳐 4 top
# 그아가리좀닥쳐 5 jungle
# 그아가리좀닥쳐 6 jungle
# 그아가리좀닥쳐 7 top
# 그아가리좀닥쳐 8 top
# 그아가리좀닥쳐 9 top
# 그아가리좀닥쳐 10 mid
# 그아가리좀닥쳐 11 mid
# 그아가리좀닥쳐 12 jungle
# 그아가리좀닥쳐 13 jungle
# 그아가리좀닥쳐 14 top
# 그아가리좀닥쳐 15 jungle
# 그아가리좀닥쳐 16 top
# 그아가리좀닥쳐 17 jungle
# 그아가리좀닥쳐 18 top
# 그아가리좀닥쳐 19 top
# 그아가리좀닥쳐 20 top
# 그아가리좀닥쳐 21 top
# 그아가리좀닥쳐 22 top
# 그아가리좀닥쳐 23 top
# 그아가리좀닥쳐 24 top
# 그아가리좀닥쳐 25 mid
# 그아가리좀닥쳐 26 top
# 그아가리좀닥쳐 27 mid
# 그아가리좀닥쳐 28 mid
# 그아가리좀닥쳐 29 mid
# 그아가리좀닥쳐 30 mid
# 찍찍이쌤유튜브 1 adc
# 찍찍이쌤유튜브 2 adc
# 찍찍이쌤유튜브 3 adc
# 찍찍이쌤유튜브 4 adc
# 찍찍이쌤유튜브 5 adc
# 찍찍이쌤유튜브 6 adc
# 찍찍이쌤유튜브 7 adc
# 찍찍이쌤유튜브 8 adc
# 찍찍이쌤유튜브 9 adc
# 찍찍이쌤유튜브 10 adc
# 찍찍이쌤유튜브 11 adc
# 찍찍이쌤유튜브 12 adc
# 찍찍이쌤유튜브 13 adc
# 찍찍이쌤유튜브 14 adc
# 찍찍이쌤유튜브 15 adc
# 찍찍이쌤유튜브 16 adc
# 찍찍이쌤유튜브 17 adc
# 찍찍이쌤유튜브 18 adc
# 찍찍이쌤유튜브 19 mid
# 찍찍이쌤유튜브 20 adc
# 찍찍이쌤유튜브 21 adc
# 찍찍이쌤유튜브 22 adc
# 찍찍이쌤유튜브 23 adc
# 찍찍이쌤유튜브 24 adc
# 찍찍이쌤유튜브 25 adc
# 찍찍이쌤유튜브 26 adc
# 찍찍이쌤유튜브 27 adc
# 찍찍이쌤유튜브 28 adc
# 찍찍이쌤유튜브 29 adc
# 찍찍이쌤유튜브 30 adc
# 반드시올라간다 1 mid
# 반드시올라간다 2 mid
# 반드시올라간다 3 mid
# 반드시올라간다 4 mid
# 반드시올라간다 5 mid
# 반드시올라간다 6 mid
# 반드시올라간다 7 mid
# 반드시올라간다 8 mid
# 반드시올라간다 9 mid
# 반드시올라간다 10 mid
# 반드시올라간다 11 mid
# 반드시올라간다 12 mid
# 반드시올라간다 13 mid
# 반드시올라간다 14 adc
# 반드시올라간다 15 adc
# 반드시올라간다 16 adc
# 반드시올라간다 17 adc
# 반드시올라간다 18 adc
# 반드시올라간다 19 support
# 반드시올라간다 20 mid
# 반드시올라간다 21 adc
# 반드시올라간다 22 adc
# 반드시올라간다 23 adc
# 반드시올라간다 24 adc
# 반드시올라간다 25 adc
# 반드시올라간다 26 adc
# 반드시올라간다 27 mid
# 반드시올라간다 28 mid
# 반드시올라간다 29 mid
# 반드시올라간다 30 mid
# 노콘거부중 1 adc
# 노콘거부중 2 jungle
# 노콘거부중 3 support
# 노콘거부중 4 mid
# 노콘거부중 5 support
# 노콘거부중 6 support
# 노콘거부중 7 support
# 노콘거부중 8 support
# 노콘거부중 9 support
# 노콘거부중 10 support
# 노콘거부중 11 support
# 노콘거부중 12 mid
# 노콘거부중 13 support
# 노콘거부중 14 jungle
# 노콘거부중 15 adc
# 노콘거부중 16 jungle
# 노콘거부중 17 adc
# 노콘거부중 18 top
# 노콘거부중 19 adc
# 노콘거부중 20 mid
# 노콘거부중 21 support
# 노콘거부중 22 support
# 노콘거부중 23 mid
# 노콘거부중 24 support
# 노콘거부중 25 support
# 노콘거부중 26 support
# 노콘거부중 27 adc
# 노콘거부중 28 support
# 노콘거부중 29 support
# 싸장님아내맛잇섭 1 adc
# 싸장님아내맛잇섭 2 support
# 싸장님아내맛잇섭 3 support
# 싸장님아내맛잇섭 4 adc
# 싸장님아내맛잇섭 5 support
# 싸장님아내맛잇섭 6 support
# 싸장님아내맛잇섭 7 jungle
# 싸장님아내맛잇섭 8 support
# 싸장님아내맛잇섭 9 support
# 싸장님아내맛잇섭 10 support
# 싸장님아내맛잇섭 11 support
# 싸장님아내맛잇섭 12 support
# 싸장님아내맛잇섭 13 adc
# 싸장님아내맛잇섭 14 top
# 싸장님아내맛잇섭 15 mid
# 싸장님아내맛잇섭 16 adc
# 싸장님아내맛잇섭 17 mid
# 싸장님아내맛잇섭 18 support
# 싸장님아내맛잇섭 19 support
# 싸장님아내맛잇섭 20 adc
# 싸장님아내맛잇섭 21 adc
# 싸장님아내맛잇섭 22 mid
# 싸장님아내맛잇섭 23 support
# 싸장님아내맛잇섭 24 jungle
# 싸장님아내맛잇섭 25 jungle
# 싸장님아내맛잇섭 26 support
# 싸장님아내맛잇섭 27 adc
# 싸장님아내맛잇섭 28 support
# 싸장님아내맛잇섭 29 support
# 싸장님아내맛잇섭 30 support
# 저능아탐지기 1 top
# 저능아탐지기 2 support
# 저능아탐지기 3 top
# 저능아탐지기 4 support
# 저능아탐지기 5 jungle
# 저능아탐지기 6 top
# 저능아탐지기 7 jungle
# 저능아탐지기 8 support
# 저능아탐지기 9 mid
# 저능아탐지기 10 top
# 저능아탐지기 11 top
# 저능아탐지기 12 mid
# 저능아탐지기 13 support
# 저능아탐지기 14 top
# 저능아탐지기 15 top
# 저능아탐지기 16 top
# 저능아탐지기 17 top
# 저능아탐지기 18 adc
# 저능아탐지기 19 adc
# 저능아탐지기 20 support
# 저능아탐지기 21 top
# 저능아탐지기 22 top
# 저능아탐지기 23 jungle
# 저능아탐지기 24 top
# 저능아탐지기 25 top
# 저능아탐지기 26 top
# 저능아탐지기 27 jungle
# 저능아탐지기 28 mid
# 저능아탐지기 29 adc
# 저능아탐지기 30 mid
# GOODBOYGH 1 jungle
# GOODBOYGH 2 mid
# GOODBOYGH 3 top
# GOODBOYGH 4 jungle
# GOODBOYGH 5 top
# GOODBOYGH 6 top
# GOODBOYGH 7 jungle
# GOODBOYGH 8 jungle
# GOODBOYGH 9 jungle
# GOODBOYGH 10 mid
# GOODBOYGH 11 mid
# GOODBOYGH 12 top
# GOODBOYGH 13 top
# GOODBOYGH 14 adc
# GOODBOYGH 15 support
# GOODBOYGH 16 top
# GOODBOYGH 17 top
# GOODBOYGH 18 top
# GOODBOYGH 19 top
# GOODBOYGH 20 top
# GOODBOYGH 21 top
# GOODBOYGH 22 top
# GOODBOYGH 23 top
# GOODBOYGH 24 top
# GOODBOYGH 25 top
# GOODBOYGH 26 top
# GOODBOYGH 27 top
# GOODBOYGH 28 top
# GOODBOYGH 29 top
# GOODBOYGH 30 top
# 백핑세번미드오픈 1 mid
# 백핑세번미드오픈 2 adc
# 백핑세번미드오픈 3 adc
# 백핑세번미드오픈 4 adc
# 백핑세번미드오픈 5 adc
# 백핑세번미드오픈 6 mid
# 백핑세번미드오픈 7 adc
# 백핑세번미드오픈 8 adc
# 백핑세번미드오픈 9 adc
# 백핑세번미드오픈 10 mid
# 백핑세번미드오픈 11 adc
# 백핑세번미드오픈 12 adc
# 백핑세번미드오픈 13 adc
# 백핑세번미드오픈 14 adc
# 백핑세번미드오픈 15 mid
# 백핑세번미드오픈 16 adc
# 백핑세번미드오픈 17 adc
# 백핑세번미드오픈 18 top
# 백핑세번미드오픈 19 adc
# 백핑세번미드오픈 20 adc
# 백핑세번미드오픈 21 top
# 백핑세번미드오픈 22 mid
# 백핑세번미드오픈 23 adc
# 백핑세번미드오픈 24 adc
# 백핑세번미드오픈 25 adc
# 백핑세번미드오픈 26 adc
# 백핑세번미드오픈 27 adc
# 백핑세번미드오픈 28 jungle
# 백핑세번미드오픈 29 adc
# 백핑세번미드오픈 30 adc
# 실리카겔 1 mid
# 실리카겔 2 top
# 실리카겔 3 mid
# 실리카겔 4 mid
# 실리카겔 5 mid
# 실리카겔 6 top
# 실리카겔 7 jungle
# 실리카겔 8 mid
# 실리카겔 9 mid
# 실리카겔 10 top
# 실리카겔 11 top
# 실리카겔 12 mid
# 실리카겔 13 jungle
# 실리카겔 14 jungle
# 실리카겔 15 jungle
# 실리카겔 16 top
# 실리카겔 17 jungle
# 실리카겔 18 mid
# 실리카겔 19 jungle
# 실리카겔 20 top
# 실리카겔 21 top
# 실리카겔 22 mid
# 실리카겔 23 mid
# 실리카겔 24 mid
# 실리카겔 25 mid
# 실리카겔 26 top
# 실리카겔 27 top
# 실리카겔 28 mid
# 실리카겔 29 mid
# 실리카겔 30 adc
# 이즈리뽕 1 jungle
# 이즈리뽕 2 jungle
# 이즈리뽕 3 jungle
# 이즈리뽕 4 jungle
# 이즈리뽕 5 jungle
# 이즈리뽕 6 jungle
# 이즈리뽕 7 jungle
# 이즈리뽕 8 jungle
# 이즈리뽕 9 jungle
# 이즈리뽕 10 jungle
# 이즈리뽕 11 jungle
# 이즈리뽕 12 jungle
# 이즈리뽕 13 jungle
# 이즈리뽕 14 jungle
# 이즈리뽕 15 jungle
# 이즈리뽕 16 jungle
# 이즈리뽕 17 jungle
# 이즈리뽕 18 jungle
# 이즈리뽕 19 jungle
# 이즈리뽕 20 jungle
# 이즈리뽕 21 adc
# 이즈리뽕 22 jungle
# 이즈리뽕 23 jungle
# 이즈리뽕 24 jungle
# 이즈리뽕 25 jungle
# 이즈리뽕 26 jungle
# 이즈리뽕 27 adc
# 이즈리뽕 28 jungle
# 이즈리뽕 29 jungle
# 이즈리뽕 30 jungle
# 응팔류준열 1 jungle
# 응팔류준열 2 jungle
# 응팔류준열 3 jungle
# 응팔류준열 4 jungle
# 응팔류준열 5 jungle
# 응팔류준열 6 jungle
# 응팔류준열 7 jungle
# 응팔류준열 8 top
# 응팔류준열 9 jungle
# 응팔류준열 10 jungle
# 응팔류준열 11 jungle
# 응팔류준열 12 jungle
# 응팔류준열 13 support
# 응팔류준열 14 support
# 응팔류준열 15 support
# 응팔류준열 16 support
# 응팔류준열 17 support
# 응팔류준열 18 support
# 응팔류준열 19 mid
# 응팔류준열 20 jungle
# 응팔류준열 21 adc
# 응팔류준열 22 top
# 응팔류준열 23 support
# 응팔류준열 24 jungle
# 응팔류준열 25 top
# 응팔류준열 26 jungle
# 응팔류준열 27 jungle
# 응팔류준열 28 jungle
# 응팔류준열 29 jungle
# 원자력노조위원장 1 top
# 원자력노조위원장 2 jungle
# 원자력노조위원장 3 jungle
# 원자력노조위원장 4 adc
# 원자력노조위원장 5 adc
# 원자력노조위원장 6 adc
# 원자력노조위원장 7 top
# 원자력노조위원장 8 top
# 원자력노조위원장 9 top
# 원자력노조위원장 10 top
# 원자력노조위원장 11 top
# 원자력노조위원장 12 top
# 원자력노조위원장 13 support
# 원자력노조위원장 14 top
# 원자력노조위원장 15 top
# 원자력노조위원장 16 top
# 원자력노조위원장 17 top
# 원자력노조위원장 18 top
# 원자력노조위원장 19 top
# 원자력노조위원장 20 jungle
# 원자력노조위원장 21 top
# 원자력노조위원장 22 top
# 원자력노조위원장 23 top
# 원자력노조위원장 24 top
# 원자력노조위원장 25 top
# 원자력노조위원장 26 top
# 원자력노조위원장 27 top
# 원자력노조위원장 28 top
# 원자력노조위원장 29 top
# 원자력노조위원장 30 jungle
# 아영이는이뻐 1 jungle
# 아영이는이뻐 2 jungle
# 아영이는이뻐 3 top
# 아영이는이뻐 4 jungle
# 아영이는이뻐 5 jungle
# 아영이는이뻐 6 jungle
# 아영이는이뻐 7 mid
# 아영이는이뻐 8 support
# 아영이는이뻐 9 jungle
# 아영이는이뻐 10 mid
# 아영이는이뻐 11 mid
# 아영이는이뻐 12 jungle
# 아영이는이뻐 13 jungle
# 아영이는이뻐 14 jungle
# 아영이는이뻐 15 support
# 아영이는이뻐 16 support
# 아영이는이뻐 17 jungle
# 아영이는이뻐 18 jungle
# 아영이는이뻐 19 jungle
# 아영이는이뻐 20 jungle
# 입털면템바로팜 1 support
# 입털면템바로팜 2 jungle
# 입털면템바로팜 3 jungle
# 입털면템바로팜 4 top
# 입털면템바로팜 5 jungle
# 입털면템바로팜 6 support
# 입털면템바로팜 7 jungle
# 입털면템바로팜 8 support
# 입털면템바로팜 9 support
# 입털면템바로팜 10 support
# 입털면템바로팜 11 support
# 입털면템바로팜 12 support
# 입털면템바로팜 13 jungle
# 입털면템바로팜 14 mid
# 입털면템바로팜 15 support
# 입털면템바로팜 16 jungle
# 입털면템바로팜 17 support
# 입털면템바로팜 18 support
# 입털면템바로팜 19 support
# 입털면템바로팜 20 support
# 입털면템바로팜 21 support
# 입털면템바로팜 22 support
# 입털면템바로팜 23 support
# 입털면템바로팜 24 support
# 입털면템바로팜 25 support
# 입털면템바로팜 26 support
# 입털면템바로팜 27 support
# 입털면템바로팜 28 support
# 입털면템바로팜 29 support
# 입털면템바로팜 30 support
# 람머르기니부릉 1 jungle
# 람머르기니부릉 2 jungle
# 람머르기니부릉 3 jungle
# 람머르기니부릉 4 jungle
# 람머르기니부릉 5 jungle
# 람머르기니부릉 6 jungle
# 람머르기니부릉 7 jungle
# 람머르기니부릉 8 jungle
# 람머르기니부릉 9 jungle
# 람머르기니부릉 10 jungle
# 람머르기니부릉 11 jungle
# 람머르기니부릉 12 jungle
# 람머르기니부릉 13 jungle
# 람머르기니부릉 14 jungle
# 람머르기니부릉 15 jungle
# 람머르기니부릉 16 jungle
# 람머르기니부릉 17 jungle
# 람머르기니부릉 18 jungle
# 람머르기니부릉 19 jungle
# 람머르기니부릉 20 jungle
# 람머르기니부릉 21 jungle
# 람머르기니부릉 22 jungle
# 람머르기니부릉 23 jungle
# 람머르기니부릉 24 jungle
# 람머르기니부릉 25 jungle
# 람머르기니부릉 26 jungle
# 람머르기니부릉 27 jungle
# 람머르기니부릉 28 jungle
# 람머르기니부릉 29 jungle
# 람머르기니부릉 30 jungle
# 군대전에다이아 1 jungle
# 군대전에다이아 2 mid
# 군대전에다이아 3 mid
# 군대전에다이아 4 jungle
# 군대전에다이아 5 jungle
# 군대전에다이아 6 jungle
# 군대전에다이아 7 jungle
# 군대전에다이아 8 jungle
# 군대전에다이아 9 jungle
# 군대전에다이아 10 adc
# 군대전에다이아 11 adc
# 군대전에다이아 12 adc
# 군대전에다이아 13 adc
# 군대전에다이아 14 jungle
# 군대전에다이아 15 jungle
# 군대전에다이아 16 adc
# 군대전에다이아 17 adc
# 군대전에다이아 18 adc
# 군대전에다이아 19 jungle
# 군대전에다이아 20 jungle
# 군대전에다이아 21 mid
# 군대전에다이아 22 mid
# 군대전에다이아 23 mid
# 군대전에다이아 24 top
# 군대전에다이아 25 mid
# 군대전에다이아 26 mid
# 군대전에다이아 27 adc
# 군대전에다이아 28 adc
# 군대전에다이아 29 adc
# 군대전에다이아 30 adc
# 몰락한왕의검 1 mid
# 몰락한왕의검 2 jungle
# 몰락한왕의검 3 jungle
# 몰락한왕의검 4 jungle
# 몰락한왕의검 5 jungle
# 몰락한왕의검 6 mid
# 몰락한왕의검 7 jungle
# 몰락한왕의검 8 jungle
# 몰락한왕의검 9 mid
# 몰락한왕의검 10 jungle
# 몰락한왕의검 11 jungle
# 몰락한왕의검 12 jungle
# 몰락한왕의검 13 mid
# 몰락한왕의검 14 jungle
# 몰락한왕의검 15 jungle
# 몰락한왕의검 16 jungle
# 몰락한왕의검 17 jungle
# 몰락한왕의검 18 support
# 몰락한왕의검 19 jungle
# 몰락한왕의검 20 top
# 몰락한왕의검 21 jungle
# 몰락한왕의검 22 jungle
# 몰락한왕의검 23 jungle
# 몰락한왕의검 24 jungle
# 몰락한왕의검 25 jungle
# 몰락한왕의검 26 jungle
# 몰락한왕의검 27 support
# 몰락한왕의검 28 jungle
# 몰락한왕의검 29 jungle
# 몰락한왕의검 30 jungle
# 통매음 1 jungle
# 통매음 2 support
# 통매음 3 jungle
# 통매음 4 jungle
# 통매음 5 top
# 통매음 6 top
# 통매음 7 top
# 통매음 8 top
# 통매음 9 support
# 통매음 10 support
# 통매음 11 top
# 통매음 12 support
# 통매음 13 support
# 통매음 14 support
# 통매음 15 support
# 통매음 16 support
# 통매음 17 jungle
# 통매음 18 jungle
# 통매음 19 jungle
# 통매음 20 jungle
# 통매음 21 support
# 통매음 22 jungle
# 통매음 23 jungle
# 통매음 24 top
# 통매음 25 jungle
# 통매음 26 jungle
# 통매음 27 jungle
# 통매음 28 jungle
# 통매음 29 jungle
# 통매음 30 jungle
# Dkinnovation 1 top
# Dkinnovation 2 top
# Dkinnovation 3 mid
# Dkinnovation 4 mid
# Dkinnovation 5 mid
# Dkinnovation 6 mid
# Dkinnovation 7 mid
# Dkinnovation 8 mid
# Dkinnovation 9 mid
# Dkinnovation 10 top
# Dkinnovation 11 mid
# Dkinnovation 12 jungle
# Dkinnovation 13 jungle
# Dkinnovation 14 jungle
# Dkinnovation 15 mid
# Dkinnovation 16 top
# Dkinnovation 17 top
# Dkinnovation 18 support
# Dkinnovation 19 top
# Dkinnovation 20 top
# Dkinnovation 21 top
# Dkinnovation 22 jungle
# Dkinnovation 23 jungle
# Dkinnovation 24 top
# Dkinnovation 25 top
# Dkinnovation 26 top
# 별솜사탕 1 adc
# 별솜사탕 2 top
# 별솜사탕 3 jungle
# 별솜사탕 4 jungle
# 별솜사탕 5 jungle
# 별솜사탕 6 jungle
# 별솜사탕 7 mid
# 별솜사탕 8 mid
# 별솜사탕 9 jungle
# 별솜사탕 10 jungle
# 별솜사탕 11 mid
# 별솜사탕 12 top
# 별솜사탕 13 top
# 별솜사탕 14 top
# 별솜사탕 15 top
# 별솜사탕 16 mid
# 별솜사탕 17 adc
# 별솜사탕 18 adc
# 별솜사탕 19 jungle
# 별솜사탕 20 adc
# 별솜사탕 21 adc
# 별솜사탕 22 adc
# 별솜사탕 23 adc
# 별솜사탕 24 adc
# 별솜사탕 25 adc
# 별솜사탕 26 adc
# 별솜사탕 27 adc
# 별솜사탕 28 adc
# 별솜사탕 29 adc
# 별솜사탕 30 adc
# 코lo나환자 1 jungle
# 코lo나환자 2 jungle
# 코lo나환자 3 jungle
# 코lo나환자 4 jungle
# 코lo나환자 5 jungle
# 코lo나환자 6 jungle
# 코lo나환자 7 jungle
# 코lo나환자 8 jungle
# 코lo나환자 9 jungle
# 코lo나환자 10 jungle
# 코lo나환자 11 jungle
# 코lo나환자 12 mid
# 코lo나환자 13 top
# 코lo나환자 14 adc
# 코lo나환자 15 adc
# 코lo나환자 16 support
# 코lo나환자 17 top
# 코lo나환자 18 top
# 코lo나환자 19 jungle
# 코lo나환자 20 support
# 코lo나환자 21 top
# 코lo나환자 22 top
# 코lo나환자 23 support
# 코lo나환자 24 support
# 코lo나환자 25 jungle
# 코lo나환자 26 jungle
# 코lo나환자 27 top
# 코lo나환자 28 top
# 코lo나환자 29 top
# 코lo나환자 30 jungle
# 물만두장인 1 support
# 물만두장인 2 adc
# 물만두장인 3 adc
# 물만두장인 4 adc
# 물만두장인 5 adc
# 물만두장인 6 adc
# 물만두장인 7 adc
# 물만두장인 8 adc
# 물만두장인 9 support
# 물만두장인 10 support
# 물만두장인 11 adc
# 물만두장인 12 support
# 물만두장인 13 support
# 물만두장인 14 adc
# 물만두장인 15 support
# 물만두장인 16 top
# 물만두장인 17 top
# 물만두장인 18 adc
# 물만두장인 19 top
# 물만두장인 20 top
# 물만두장인 21 top
# 물만두장인 22 top
# 물만두장인 23 top
# 물만두장인 24 adc
# 물만두장인 25 adc
# 물만두장인 26 adc
# 물만두장인 27 adc
# 물만두장인 28 adc
# 물만두장인 29 adc
# 물만두장인 30 adc
# 하우지꼬부기 1 adc
# 하우지꼬부기 2 mid
# 하우지꼬부기 3 mid
# 하우지꼬부기 4 mid
# 하우지꼬부기 5 mid
# 하우지꼬부기 6 mid
# 하우지꼬부기 7 mid
# 하우지꼬부기 8 mid
# 하우지꼬부기 9 mid
# 하우지꼬부기 10 mid
# 하우지꼬부기 11 mid
# 하우지꼬부기 12 mid
# 하우지꼬부기 13 mid
# 하우지꼬부기 14 mid
# 하우지꼬부기 15 support
# 하우지꼬부기 16 adc
# 하우지꼬부기 17 mid
# 하우지꼬부기 18 mid
# 하우지꼬부기 19 support
# 하우지꼬부기 20 mid
# 하우지꼬부기 21 mid
# 하우지꼬부기 22 mid
# 하우지꼬부기 23 mid
# 하우지꼬부기 24 mid
# 하우지꼬부기 25 mid
# 하우지꼬부기 26 mid
# 하우지꼬부기 27 mid
# 하우지꼬부기 28 adc
# 하우지꼬부기 29 mid
# 하우지꼬부기 30 mid
# 땅떠기 1 adc
# 땅떠기 2 support
# 땅떠기 3 support
# 땅떠기 4 support
# 땅떠기 5 support
# 땅떠기 6 support
# 땅떠기 7 adc
# 땅떠기 8 mid
# 땅떠기 9 support
# 땅떠기 10 support
# 땅떠기 11 adc
# 땅떠기 12 mid
# 땅떠기 13 top
# 땅떠기 14 jungle
# 땅떠기 15 adc
# 땅떠기 16 support
# 땅떠기 17 top
# 땅떠기 18 top
# 땅떠기 19 support
# 땅떠기 20 support
# 땅떠기 21 support
# 땅떠기 22 support
# 땅떠기 23 support
# 땅떠기 24 support
# 땅떠기 25 mid
# 땅떠기 26 mid
# 땅떠기 27 mid
# 땅떠기 28 mid
# 땅떠기 29 mid
# 땅떠기 30 mid
# sorroda 1 top
# sorroda 2 top
# sorroda 3 top
# sorroda 4 top
# sorroda 5 top
# sorroda 6 support
# sorroda 7 top
# sorroda 8 top
# sorroda 9 mid
# sorroda 10 top
# sorroda 11 mid
# sorroda 12 top
# sorroda 13 mid
# sorroda 14 mid
# sorroda 15 top
# sorroda 16 mid
# sorroda 17 top
# sorroda 18 top
# sorroda 19 top
# sorroda 20 top
# sorroda 21 top
# sorroda 22 top
# sorroda 23 top
# 칼바람나락소라카 1 top
# 칼바람나락소라카 2 jungle
# 칼바람나락소라카 3 jungle
# 칼바람나락소라카 4 support
# 칼바람나락소라카 5 adc
# 칼바람나락소라카 6 support
# 칼바람나락소라카 7 support
# 칼바람나락소라카 8 support
# 칼바람나락소라카 9 top
# 칼바람나락소라카 10 support
# 칼바람나락소라카 11 top
# 칼바람나락소라카 12 jungle
# 칼바람나락소라카 13 adc
# 칼바람나락소라카 14 support
# 칼바람나락소라카 15 support
# 칼바람나락소라카 16 support
# 칼바람나락소라카 17 jungle
# 칼바람나락소라카 18 support
# 칼바람나락소라카 19 support
# 칼바람나락소라카 20 support
# 칼바람나락소라카 21 support
# 칼바람나락소라카 22 mid
# 칼바람나락소라카 23 support
# 칼바람나락소라카 24 support
# 칼바람나락소라카 25 support
# 칼바람나락소라카 26 top
# 칼바람나락소라카 27 support
# 칼바람나락소라카 28 top
# 칼바람나락소라카 29 top
# 칼바람나락소라카 30 support
# 바람에게 1 support
# 바람에게 2 support
# 바람에게 3 adc
# 바람에게 4 support
# 바람에게 5 jungle
# 바람에게 6 support
# 바람에게 7 mid
# 바람에게 8 top
# 바람에게 9 support
# 바람에게 10 top
# 바람에게 11 adc
# 바람에게 12 mid
# 바람에게 13 jungle
# 바람에게 14 support
# 바람에게 15 jungle
# 바람에게 16 jungle
# 바람에게 17 adc
# 바람에게 18 mid
# 바람에게 19 jungle
# 바람에게 20 jungle
# 바람에게 21 mid
# 바람에게 22 jungle
# 바람에게 23 mid
# 바람에게 24 jungle
# 바람에게 25 mid
# 바람에게 26 jungle
# 바람에게 27 support
# 바람에게 28 top
# 바람에게 29 adc
# 바람에게 30 support
# 조헤리니 1 jungle
# 조헤리니 2 mid
# 조헤리니 3 support
# 조헤리니 4 support
# 조헤리니 5 support
# 조헤리니 6 support
# 조헤리니 7 support
# 조헤리니 8 jungle
# 조헤리니 9 jungle
# 조헤리니 10 support
# 조헤리니 11 top
# 조헤리니 12 jungle
# 조헤리니 13 jungle
# 조헤리니 14 top
# 조헤리니 15 top
# 조헤리니 16 top
# 조헤리니 17 top
# 조헤리니 18 jungle
# 조헤리니 19 jungle
# 조헤리니 20 jungle
# 조헤리니 21 support
# 조헤리니 22 adc
# 조헤리니 23 adc
# 조헤리니 24 top
# 조헤리니 25 adc
# 조헤리니 26 adc
# 조헤리니 27 adc
# 조헤리니 28 adc
# 조헤리니 29 adc
# 조헤리니 30 adc
# 밤빵맛 1 top
# 밤빵맛 2 top
# 밤빵맛 3 top
# 밤빵맛 4 support
# 밤빵맛 5 top
# 밤빵맛 6 jungle
# 밤빵맛 7 jungle
# 밤빵맛 8 jungle
# 밤빵맛 9 top
# 밤빵맛 10 jungle
# 밤빵맛 11 jungle
# 밤빵맛 12 jungle
# 밤빵맛 13 jungle
# 밤빵맛 14 jungle
# 밤빵맛 15 jungle
# 밤빵맛 16 jungle
# 밤빵맛 17 jungle
# 밤빵맛 18 jungle
# 밤빵맛 19 jungle
# 밤빵맛 20 jungle
# 밤빵맛 21 jungle
# 밤빵맛 22 support
# 밤빵맛 23 jungle
# 밤빵맛 24 jungle
# 밤빵맛 25 support
# 밤빵맛 26 jungle
# 밤빵맛 27 top
# 밤빵맛 28 support
# 밤빵맛 29 jungle
# 밤빵맛 30 support
# 66x 1 mid
# 66x 2 mid
# 66x 3 jungle
# 66x 4 jungle
# 66x 5 adc
# 66x 6 support
# 66x 7 adc
# 66x 8 mid
# 66x 9 support
# 66x 10 jungle
# 66x 11 jungle
# 66x 12 jungle
# 66x 13 adc
# 66x 14 adc
# 66x 15 jungle
# 66x 16 jungle
# 66x 17 adc
# 66x 18 adc
# 66x 19 jungle
# 66x 20 jungle
# 66x 21 adc
# 66x 22 adc
# 66x 23 adc
# 66x 24 mid
# 66x 25 adc
# 66x 26 adc
# 66x 27 adc
# 66x 28 adc
# 66x 29 adc
# 66x 30 adc
# 신분을숨긴소녀 1 support
# 신분을숨긴소녀 2 support
# 신분을숨긴소녀 3 support
# 신분을숨긴소녀 4 support
# 신분을숨긴소녀 5 mid
# 신분을숨긴소녀 6 support
# 신분을숨긴소녀 7 support
# 신분을숨긴소녀 8 support
# 신분을숨긴소녀 9 support
# 신분을숨긴소녀 10 mid
# 신분을숨긴소녀 11 support
# 신분을숨긴소녀 12 support
# 신분을숨긴소녀 13 support
# 신분을숨긴소녀 14 support
# 신분을숨긴소녀 15 support
# 신분을숨긴소녀 16 adc
# 신분을숨긴소녀 17 adc
# 신분을숨긴소녀 18 jungle
# 신분을숨긴소녀 19 jungle
# 신분을숨긴소녀 20 jungle
# 신분을숨긴소녀 21 top
# 신분을숨긴소녀 22 support
# 신분을숨긴소녀 23 jungle
# 신분을숨긴소녀 24 mid
# 신분을숨긴소녀 25 mid
# 신분을숨긴소녀 26 mid
# 신분을숨긴소녀 27 mid
# 신분을숨긴소녀 28 top
# 신분을숨긴소녀 29 adc
# 신분을숨긴소녀 30 mid
# oklol 1 support
# oklol 2 adc
# oklol 3 support
# oklol 4 adc
# oklol 5 support
# oklol 6 mid
# oklol 7 support
# oklol 8 support
# oklol 9 support
# oklol 10 support
# oklol 11 support
# oklol 12 support
# oklol 13 adc
# oklol 14 adc
# oklol 15 support
# oklol 16 support
# oklol 17 support
# oklol 18 support
# oklol 19 adc
# oklol 20 support
# oklol 21 support
# oklol 22 support
# oklol 23 adc
# oklol 24 support
# oklol 25 support
# oklol 26 support
# oklol 27 support
# oklol 28 support
# oklol 29 support
# oklol 30 support
# WhenDovesCry 1 top
# WhenDovesCry 2 jungle
# WhenDovesCry 3 adc
# WhenDovesCry 4 adc
# WhenDovesCry 5 adc
# WhenDovesCry 6 adc
# WhenDovesCry 7 top
# WhenDovesCry 8 adc
# WhenDovesCry 9 jungle
# WhenDovesCry 10 adc
# WhenDovesCry 11 adc
# WhenDovesCry 12 top
# WhenDovesCry 13 adc
# WhenDovesCry 14 adc
# WhenDovesCry 15 adc
# WhenDovesCry 16 top
# WhenDovesCry 17 jungle
# WhenDovesCry 18 top
# WhenDovesCry 19 top
# WhenDovesCry 20 mid
# WhenDovesCry 21 jungle
# WhenDovesCry 22 jungle
# WhenDovesCry 23 top
# WhenDovesCry 24 mid
# WhenDovesCry 25 top
# WhenDovesCry 26 jungle
# WhenDovesCry 27 mid
# WhenDovesCry 28 jungle
# WhenDovesCry 29 jungle
# WhenDovesCry 30 jungle
# 생각대로기사문의 1 top
# 생각대로기사문의 2 top
# 생각대로기사문의 3 top
# 생각대로기사문의 4 top
# 생각대로기사문의 5 top
# 생각대로기사문의 6 top
# 생각대로기사문의 7 top
# 생각대로기사문의 8 top
# 생각대로기사문의 9 top
# 생각대로기사문의 10 top
# 생각대로기사문의 11 top
# 생각대로기사문의 12 top
# 생각대로기사문의 13 top
# 생각대로기사문의 14 top
# 생각대로기사문의 15 top
# 생각대로기사문의 16 top
# 생각대로기사문의 17 top
# 생각대로기사문의 18 top
# 생각대로기사문의 19 jungle
# 생각대로기사문의 20 jungle
# 생각대로기사문의 21 jungle
# 생각대로기사문의 22 top
# 생각대로기사문의 23 top
# 생각대로기사문의 24 top
# 생각대로기사문의 25 top
# 생각대로기사문의 26 top
# 생각대로기사문의 27 top
# 생각대로기사문의 28 top
# 생각대로기사문의 29 top
# 생각대로기사문의 30 top
# 부바왓슨 1 mid
# 부바왓슨 2 top
# 부바왓슨 3 top
# 부바왓슨 4 top
# 부바왓슨 5 top
# 부바왓슨 6 top
# 부바왓슨 7 top
# 부바왓슨 8 top
# 부바왓슨 9 top
# 부바왓슨 10 top
# 부바왓슨 11 top
# 부바왓슨 12 top
# 부바왓슨 13 top
# 부바왓슨 14 mid
# 부바왓슨 15 support
# 부바왓슨 16 support
# 부바왓슨 17 top
# 부바왓슨 18 top
# 부바왓슨 19 top
# 부바왓슨 20 jungle
# 부바왓슨 21 jungle
# 부바왓슨 22 jungle
# 부바왓슨 23 top
# 부바왓슨 24 top
# 부바왓슨 25 jungle
# 부바왓슨 26 jungle
# 부바왓슨 27 support
# 부바왓슨 28 support
# 부바왓슨 29 support
# 부바왓슨 30 support
# AD킬러말파 1 top
# AD킬러말파 2 top
# AD킬러말파 3 top
# AD킬러말파 4 top
# AD킬러말파 5 top
# AD킬러말파 6 top
# AD킬러말파 7 top
# AD킬러말파 8 top
# AD킬러말파 9 support
# AD킬러말파 10 mid
# AD킬러말파 11 top
# AD킬러말파 12 top
# AD킬러말파 13 top
# AD킬러말파 14 top
# AD킬러말파 15 top
# AD킬러말파 16 top
# AD킬러말파 17 top
# AD킬러말파 18 top
# AD킬러말파 19 top
# AD킬러말파 20 mid
# AD킬러말파 21 top
# AD킬러말파 22 top
# AD킬러말파 23 top
# AD킬러말파 24 top
# AD킬러말파 25 top
# AD킬러말파 26 top
# AD킬러말파 27 top
# AD킬러말파 28 top
# AD킬러말파 29 top
# AD킬러말파 30 top
# 미오맘 1 adc
# 미오맘 2 adc
# 미오맘 3 adc
# 미오맘 4 adc
# 미오맘 5 adc
# 미오맘 6 adc
# 미오맘 7 adc
# 미오맘 8 adc
# 미오맘 9 adc
# 미오맘 10 adc
# 미오맘 11 adc
# 미오맘 12 adc
# 미오맘 13 adc
# 미오맘 14 adc
# 미오맘 15 adc
# 미오맘 16 adc
# 미오맘 17 adc
# 미오맘 18 adc
# 미오맘 19 adc
# 미오맘 20 adc
# 미오맘 21 adc
# 미오맘 22 adc
# 미오맘 23 adc
# 미오맘 24 adc
# 미오맘 25 adc
# 미오맘 26 adc
# 미오맘 27 adc
# 미오맘 28 adc
# 미오맘 29 adc
# 미오맘 30 adc
# 두툼한고기카레 1 mid
# 두툼한고기카레 2 jungle
# 두툼한고기카레 3 jungle
# 두툼한고기카레 4 jungle
# 두툼한고기카레 5 jungle
# 두툼한고기카레 6 jungle
# 두툼한고기카레 7 adc
# 두툼한고기카레 8 adc
# 두툼한고기카레 9 adc
# 두툼한고기카레 10 adc
# 두툼한고기카레 11 adc
# 두툼한고기카레 12 jungle
# 두툼한고기카레 13 jungle
# 두툼한고기카레 14 jungle
# 두툼한고기카레 15 jungle
# 두툼한고기카레 16 jungle
# 두툼한고기카레 17 top
# 두툼한고기카레 18 top
# 두툼한고기카레 19 support
# 두툼한고기카레 20 jungle
# 두툼한고기카레 21 jungle
# 두툼한고기카레 22 jungle
# 두툼한고기카레 23 jungle
# 두툼한고기카레 24 jungle
# 두툼한고기카레 25 jungle
# 두툼한고기카레 26 jungle
# 두툼한고기카레 27 jungle
# 두툼한고기카레 28 jungle
# 두툼한고기카레 29 mid
# 냥뀨 1 mid
# 냥뀨 2 top
# 냥뀨 3 top
# 냥뀨 4 adc
# 냥뀨 5 adc
# 냥뀨 6 adc
# 냥뀨 7 adc
# 냥뀨 8 jungle
# 냥뀨 9 top
# 냥뀨 10 adc
# 냥뀨 11 top
# 냥뀨 12 top
# 냥뀨 13 top
# 냥뀨 14 top
# 냥뀨 15 adc
# 냥뀨 16 top
# 냥뀨 17 top
# 냥뀨 18 support
# 냥뀨 19 top
# 냥뀨 20 adc
# 냥뀨 21 mid
# 냥뀨 22 jungle
# 냥뀨 23 top
# 냥뀨 24 adc
# 냥뀨 25 top
# 냥뀨 26 adc
# 냥뀨 27 top
# 냥뀨 28 jungle
# 냥뀨 29 adc
# 냥뀨 30 adc
# gk2yo 1 jungle
# gk2yo 2 support
# gk2yo 3 support
# gk2yo 4 top
# gk2yo 5 top
# gk2yo 6 top
# gk2yo 7 top
# gk2yo 8 mid
# gk2yo 9 jungle
# gk2yo 10 adc
# gk2yo 11 adc
# gk2yo 12 mid
# gk2yo 13 jungle
# gk2yo 14 jungle
# gk2yo 15 adc
# gk2yo 16 jungle
# gk2yo 17 adc
# gk2yo 18 adc
# gk2yo 19 jungle
# gk2yo 20 support
# gk2yo 21 top
# gk2yo 22 top
# gk2yo 23 top
# gk2yo 24 top
# gk2yo 25 top
# gk2yo 26 top
# gk2yo 27 jungle
# gk2yo 28 top
# gk2yo 29 mid
# 토끼는빠르지 1 top
# 토끼는빠르지 2 top
# 토끼는빠르지 3 top
# 토끼는빠르지 4 top
# 토끼는빠르지 5 support
# 토끼는빠르지 6 support
# 토끼는빠르지 7 support
# 토끼는빠르지 8 support
# 토끼는빠르지 9 support
# 토끼는빠르지 10 support
# 토끼는빠르지 11 support
# 토끼는빠르지 12 top
# 토끼는빠르지 13 mid
# 토끼는빠르지 14 support
# 토끼는빠르지 15 mid
# 토끼는빠르지 16 mid
# 토끼는빠르지 17 mid
# 토끼는빠르지 18 support
# 토끼는빠르지 19 top
# 토끼는빠르지 20 mid
# 토끼는빠르지 21 support
# 토끼는빠르지 22 support
# 토끼는빠르지 23 support
# 토끼는빠르지 24 support
# 토끼는빠르지 25 support
# 토끼는빠르지 26 support
# 토끼는빠르지 27 top
# 토끼는빠르지 28 support
# 토끼는빠르지 29 support
# 토끼는빠르지 30 top
# jesusshot 1 support
# jesusshot 2 support
# jesusshot 3 support
# jesusshot 4 mid
# jesusshot 5 adc
# jesusshot 6 mid
# jesusshot 7 mid
# jesusshot 8 mid
# jesusshot 9 mid
# jesusshot 10 mid
# jesusshot 11 support
# jesusshot 12 mid
# jesusshot 13 mid
# jesusshot 14 mid
# jesusshot 15 support
# jesusshot 16 mid
# jesusshot 17 mid
# jesusshot 18 mid
# jesusshot 19 support
# jesusshot 20 top
# jesusshot 21 top
# jesusshot 22 mid
# jesusshot 23 mid
# jesusshot 24 support
# jesusshot 25 support
# jesusshot 26 support
# jesusshot 27 mid
# jesusshot 28 mid
# jesusshot 29 adc
# jesusshot 30 support
# 럐영 1 adc
# 럐영 2 mid
# 럐영 3 top
# 럐영 4 jungle
# 럐영 5 adc
# 럐영 6 jungle
# 럐영 7 jungle
# 럐영 8 jungle
# 럐영 9 jungle
# 럐영 10 jungle
# 럐영 11 jungle
# 럐영 12 jungle
# 럐영 13 jungle
# 럐영 14 jungle
# 럐영 15 jungle
# 럐영 16 jungle
# 럐영 17 mid
# 럐영 18 support
# 럐영 19 jungle
# 럐영 20 adc
# 럐영 21 top
# 럐영 22 jungle
# 럐영 23 jungle
# 럐영 24 jungle
# 럐영 25 jungle
# 럐영 26 jungle
# 럐영 27 jungle
# z주노z 1 jungle
# z주노z 2 jungle
# z주노z 3 jungle
# z주노z 4 jungle
# z주노z 5 jungle
# z주노z 6 top
# z주노z 7 mid
# z주노z 8 adc
# z주노z 9 adc
# z주노z 10 jungle
# z주노z 11 adc
# z주노z 12 adc
# z주노z 13 mid
# z주노z 14 adc
# z주노z 15 mid
# z주노z 16 mid
# z주노z 17 top
# z주노z 18 jungle
# z주노z 19 jungle
# z주노z 20 jungle
# z주노z 21 jungle
# z주노z 22 top
# z주노z 23 adc
# z주노z 24 jungle
# z주노z 25 jungle
# z주노z 26 adc
# z주노z 27 adc
# z주노z 28 top
# z주노z 29 jungle
# z주노z 30 jungle
# 원양어선노예 1 adc
# 원양어선노예 2 jungle
# 원양어선노예 3 jungle
# 원양어선노예 4 jungle
# 원양어선노예 5 adc
# 원양어선노예 6 adc
# 원양어선노예 7 adc
# 원양어선노예 8 support
# 원양어선노예 9 adc
# 원양어선노예 10 top
# 원양어선노예 11 top
# 원양어선노예 12 jungle
# 원양어선노예 13 support
# 원양어선노예 14 jungle
# 원양어선노예 15 adc
# 원양어선노예 16 top
# 원양어선노예 17 top
# 원양어선노예 18 adc
# 원양어선노예 19 top
# 원양어선노예 20 top
# 원양어선노예 21 top
# 원양어선노예 22 top
# 원양어선노예 23 top
# 원양어선노예 24 top
# 원양어선노예 25 jungle
# 원양어선노예 26 jungle
# 원양어선노예 27 jungle
# 원양어선노예 28 jungle
# 원양어선노예 29 adc
# 원양어선노예 30 adc
# 유미는츄르츄릅 1 top
# 유미는츄르츄릅 2 adc
# 유미는츄르츄릅 3 adc
# 유미는츄르츄릅 4 mid
# 유미는츄르츄릅 5 top
# 유미는츄르츄릅 6 adc
# 유미는츄르츄릅 7 top
# 유미는츄르츄릅 8 adc
# 유미는츄르츄릅 9 top
# 유미는츄르츄릅 10 top
# 유미는츄르츄릅 11 support
# 유미는츄르츄릅 12 jungle
# 유미는츄르츄릅 13 jungle
# 유미는츄르츄릅 14 jungle
# 유미는츄르츄릅 15 adc
# 유미는츄르츄릅 16 mid
# 유미는츄르츄릅 17 adc
# 유미는츄르츄릅 18 adc
# 유미는츄르츄릅 19 adc
# 유미는츄르츄릅 20 top
# 유미는츄르츄릅 21 top
# 유미는츄르츄릅 22 top
# 유미는츄르츄릅 23 top
# 유미는츄르츄릅 24 adc
# 유미는츄르츄릅 25 jungle
# 유미는츄르츄릅 26 top
# 유미는츄르츄릅 27 jungle
# 유미는츄르츄릅 28 support
# 유미는츄르츄릅 29 mid
# 유미는츄르츄릅 30 jungle
# 정글탓이얌 1 top
# 정글탓이얌 2 adc
# 정글탓이얌 3 top
# 정글탓이얌 4 adc
# 정글탓이얌 5 adc
# 정글탓이얌 6 adc
# 정글탓이얌 7 mid
# 정글탓이얌 8 adc
# 정글탓이얌 9 mid
# 정글탓이얌 10 jungle
# 정글탓이얌 11 top
# 정글탓이얌 12 top
# 정글탓이얌 13 adc
# 정글탓이얌 14 mid
# 정글탓이얌 15 adc
# 정글탓이얌 16 mid
# 정글탓이얌 17 jungle
# 정글탓이얌 18 adc
# 정글탓이얌 19 mid
# 정글탓이얌 20 mid
# 정글탓이얌 21 mid
# 정글탓이얌 22 mid
# 정글탓이얌 23 mid
# 정글탓이얌 24 mid
# 정글탓이얌 25 adc
# 정글탓이얌 26 adc
# 정글탓이얌 27 adc
# 정글탓이얌 28 top
# 정글탓이얌 29 mid
# 정글탓이얌 30 adc
# 낙지탕탕이이 1 adc
# 낙지탕탕이이 2 adc
# 낙지탕탕이이 3 adc
# 낙지탕탕이이 4 adc
# 낙지탕탕이이 5 jungle
# 낙지탕탕이이 6 adc
# 낙지탕탕이이 7 adc
# 낙지탕탕이이 8 mid
# 낙지탕탕이이 9 adc
# 낙지탕탕이이 10 mid
# 낙지탕탕이이 11 support
# 낙지탕탕이이 12 jungle
# 낙지탕탕이이 13 adc
# 낙지탕탕이이 14 jungle
# 낙지탕탕이이 15 adc
# 낙지탕탕이이 16 top
# 낙지탕탕이이 17 mid
# 낙지탕탕이이 18 support
# 낙지탕탕이이 19 top
# 낙지탕탕이이 20 mid
# 낙지탕탕이이 21 jungle
# 낙지탕탕이이 22 support
# 낙지탕탕이이 23 jungle
# 낙지탕탕이이 24 adc
# 낙지탕탕이이 25 support
# 낙지탕탕이이 26 jungle
# 낙지탕탕이이 27 jungle
# 낙지탕탕이이 28 support
# 안정적인후반폿 1 support
# 안정적인후반폿 2 support
# 안정적인후반폿 3 support
# 안정적인후반폿 4 support
# 안정적인후반폿 5 support
# 안정적인후반폿 6 support
# 안정적인후반폿 7 jungle
# 안정적인후반폿 8 support
# 안정적인후반폿 9 mid
# 안정적인후반폿 10 mid
# 안정적인후반폿 11 adc
# 안정적인후반폿 12 mid
# 안정적인후반폿 13 mid
# 안정적인후반폿 14 support
# 안정적인후반폿 15 mid
# 안정적인후반폿 16 support
# 안정적인후반폿 17 support
# 안정적인후반폿 18 support
# 안정적인후반폿 19 mid
# 안정적인후반폿 20 mid
# 안정적인후반폿 21 mid
# 안정적인후반폿 22 mid
# 안정적인후반폿 23 mid
# 안정적인후반폿 24 mid
# 안정적인후반폿 25 mid
# 안정적인후반폿 26 support
# 안정적인후반폿 27 mid
# 안정적인후반폿 28 mid
# 안정적인후반폿 29 support
# 구르미그린별빛 1 mid
# 구르미그린별빛 2 mid
# 구르미그린별빛 3 mid
# 구르미그린별빛 4 mid
# 구르미그린별빛 5 mid
# 구르미그린별빛 6 mid
# 구르미그린별빛 7 mid
# 구르미그린별빛 8 mid
# 구르미그린별빛 9 mid
# 구르미그린별빛 10 mid
# 구르미그린별빛 11 mid
# 구르미그린별빛 12 mid
# 구르미그린별빛 13 mid
# 구르미그린별빛 14 mid
# 구르미그린별빛 15 mid
# 구르미그린별빛 16 mid
# 구르미그린별빛 17 mid
# 구르미그린별빛 18 mid
# 구르미그린별빛 19 mid
# 구르미그린별빛 20 mid
# 구르미그린별빛 21 mid
# 구르미그린별빛 22 mid
# 구르미그린별빛 23 mid
# 구르미그린별빛 24 jungle
# 구르미그린별빛 25 mid
# 구르미그린별빛 26 mid
# 구르미그린별빛 27 mid
# 구르미그린별빛 28 mid
# 구르미그린별빛 29 mid
# 구르미그린별빛 30 mid
# 테콩 1 mid
# 테콩 2 support
# 테콩 3 support
# 테콩 4 support
# 테콩 5 support
# 테콩 6 mid
# 테콩 7 mid
# 테콩 8 mid
# 테콩 9 jungle
# 테콩 10 support
# 테콩 11 mid
# 테콩 12 mid
# 테콩 13 mid
# 테콩 14 mid
# 테콩 15 jungle
# 테콩 16 jungle
# 테콩 17 mid
# 테콩 18 mid
# 테콩 19 mid
# 테콩 20 mid
# 테콩 21 support
# 테콩 22 support
# 테콩 23 mid
# 테콩 24 mid
# 테콩 25 mid
# 테콩 26 mid
# 테콩 27 mid
# 테콩 28 mid
# 테콩 29 mid
# 테콩 30 mid
# 김초토 1 support
# 김초토 2 top
# 김초토 3 jungle
# 김초토 4 support
# 김초토 5 adc
# 김초토 6 support
# 김초토 7 top
# 김초토 8 mid
# 김초토 9 adc
# 김초토 10 top
# 김초토 11 adc
# 김초토 12 support
# 김초토 13 adc
# 김초토 14 support
# 김초토 15 top
# 김초토 16 jungle
# 김초토 17 jungle
# 김초토 18 mid
# 김초토 19 jungle
# 김초토 20 adc
# 김초토 21 support
# 김초토 22 support
# 김초토 23 jungle
# 김초토 24 jungle
# 김초토 25 support
# 김초토 26 top
# 김초토 27 adc
# 김초토 28 adc
# 김초토 29 adc
# 김초토 30 adc
# 뽕긴v 1 mid
# 뽕긴v 2 mid
# 뽕긴v 3 top
# 뽕긴v 4 mid
# 뽕긴v 5 mid
# 뽕긴v 6 mid
# 뽕긴v 7 mid
# 뽕긴v 8 mid
# 뽕긴v 9 jungle
# 뽕긴v 10 mid
# 뽕긴v 11 mid
# 뽕긴v 12 mid
# 뽕긴v 13 top
# 뽕긴v 14 mid
# 뽕긴v 15 mid
# 뽕긴v 16 mid
# 뽕긴v 17 adc
# 뽕긴v 18 mid
# 뽕긴v 19 mid
# 뽕긴v 20 mid
# 뽕긴v 21 adc
# 뽕긴v 22 adc
# 뽕긴v 23 mid
# 뽕긴v 24 mid
# 뽕긴v 25 mid
# 뽕긴v 26 adc
# 뽕긴v 27 mid
# 뽕긴v 28 mid
# 뽕긴v 29 adc
# 뽕긴v 30 adc
# 뽀득뽀득퐁퐁 1 top
# 뽀득뽀득퐁퐁 2 adc
# 뽀득뽀득퐁퐁 3 adc
# 뽀득뽀득퐁퐁 4 mid
# 뽀득뽀득퐁퐁 5 adc
# 뽀득뽀득퐁퐁 6 top
# 뽀득뽀득퐁퐁 7 jungle
# 뽀득뽀득퐁퐁 8 jungle
# 뽀득뽀득퐁퐁 9 jungle
# 뽀득뽀득퐁퐁 10 jungle
# 뽀득뽀득퐁퐁 11 jungle
# 뽀득뽀득퐁퐁 12 adc
# 뽀득뽀득퐁퐁 13 mid
# 뽀득뽀득퐁퐁 14 mid
# 뽀득뽀득퐁퐁 15 mid
# 뽀득뽀득퐁퐁 16 jungle
# 뽀득뽀득퐁퐁 17 mid
# 뽀득뽀득퐁퐁 18 mid
# 뽀득뽀득퐁퐁 19 jungle
# 뽀득뽀득퐁퐁 20 jungle
# 뽀득뽀득퐁퐁 21 support
# 뽀득뽀득퐁퐁 22 jungle
# 뽀득뽀득퐁퐁 23 top
# 뽀득뽀득퐁퐁 24 top
# 뽀득뽀득퐁퐁 25 mid
# 뽀득뽀득퐁퐁 26 mid
# 뽀득뽀득퐁퐁 27 adc
# 뽀득뽀득퐁퐁 28 mid
# 뽀득뽀득퐁퐁 29 top
# 뽀득뽀득퐁퐁 30 jungle
# 소추감별사 1 adc
# 소추감별사 2 top
# 소추감별사 3 mid
# 소추감별사 4 adc
# 소추감별사 5 adc
# 소추감별사 6 mid
# 소추감별사 7 mid
# 소추감별사 8 mid
# 소추감별사 9 support
# 소추감별사 10 mid
# 소추감별사 11 support
# 소추감별사 12 support
# 소추감별사 13 support
# 소추감별사 14 support
# 소추감별사 15 mid
# 소추감별사 16 top
# 소추감별사 17 adc
# 소추감별사 18 top
# 소추감별사 19 adc
# 소추감별사 20 top
# 소추감별사 21 mid
# 소추감별사 22 adc
# 소추감별사 23 adc
# 소추감별사 24 mid
# 소추감별사 25 jungle
# 소추감별사 26 mid
# 소추감별사 27 adc
# 소추감별사 28 top
# 소추감별사 29 top
# 정글엄마사냥꾼 1 top
# 정글엄마사냥꾼 2 top
# 정글엄마사냥꾼 3 jungle
# 정글엄마사냥꾼 4 mid
# 정글엄마사냥꾼 5 top
# 정글엄마사냥꾼 6 jungle
# 정글엄마사냥꾼 7 adc
# 정글엄마사냥꾼 8 jungle
# 정글엄마사냥꾼 9 jungle
# 정글엄마사냥꾼 10 jungle
# 정글엄마사냥꾼 11 jungle
# 정글엄마사냥꾼 12 top
# 정글엄마사냥꾼 13 top
# 정글엄마사냥꾼 14 jungle
# 정글엄마사냥꾼 15 jungle
# 정글엄마사냥꾼 16 jungle
# 정글엄마사냥꾼 17 jungle
# 정글엄마사냥꾼 18 jungle
# 정글엄마사냥꾼 19 jungle
# 정글엄마사냥꾼 20 jungle
# 정글엄마사냥꾼 21 jungle
# 정글엄마사냥꾼 22 jungle
# 정글엄마사냥꾼 23 jungle
# 정글엄마사냥꾼 24 jungle
# 정글엄마사냥꾼 25 jungle
# 정글엄마사냥꾼 26 jungle
# 정글엄마사냥꾼 27 jungle
# 정글엄마사냥꾼 28 jungle
# 정글엄마사냥꾼 29 jungle
# 정글엄마사냥꾼 30 jungle
# 헤이스툐 1 support
# 헤이스툐 2 support
# 헤이스툐 3 support
# 헤이스툐 4 support
# 헤이스툐 5 support
# 헤이스툐 6 support
# 헤이스툐 7 support
# 헤이스툐 8 support
# 헤이스툐 9 support
# 헤이스툐 10 support
# 헤이스툐 11 support
# 헤이스툐 12 support
# 헤이스툐 13 support
# 헤이스툐 14 support
# 헤이스툐 15 support
# 헤이스툐 16 support
# 헤이스툐 17 support
# 헤이스툐 18 support
# 헤이스툐 19 support
# 헤이스툐 20 support
# 헤이스툐 21 support
# 헤이스툐 22 support
# 헤이스툐 23 support
# 헤이스툐 24 support
# 헤이스툐 25 support
# 헤이스툐 26 support
# 헤이스툐 27 support
# 헤이스툐 28 support
# 헤이스툐 29 support
# 헤이스툐 30 support
# 고기는몸에좋다 1 jungle
# 고기는몸에좋다 2 jungle
# 고기는몸에좋다 3 jungle
# 고기는몸에좋다 4 support
# 고기는몸에좋다 5 support
# 고기는몸에좋다 6 top
# 고기는몸에좋다 7 top
# 고기는몸에좋다 8 support
# 고기는몸에좋다 9 support
# 고기는몸에좋다 10 top
# 고기는몸에좋다 11 jungle
# 고기는몸에좋다 12 jungle
# 고기는몸에좋다 13 jungle
# 고기는몸에좋다 14 jungle
# 고기는몸에좋다 15 jungle
# 고기는몸에좋다 16 support
# 고기는몸에좋다 17 support
# 고기는몸에좋다 18 jungle
# 고기는몸에좋다 19 adc
# 고기는몸에좋다 20 jungle
# 고기는몸에좋다 21 jungle
# 고기는몸에좋다 22 jungle
# 고기는몸에좋다 23 jungle
# 고기는몸에좋다 24 jungle
# 고기는몸에좋다 25 jungle
# 고기는몸에좋다 26 jungle
# 고기는몸에좋다 27 jungle
# 고기는몸에좋다 28 jungle
# 고기는몸에좋다 29 jungle
# 고기는몸에좋다 30 jungle
# 갱와봐개때려줄게 1 top
# 갱와봐개때려줄게 2 support
# 갱와봐개때려줄게 3 support
# 갱와봐개때려줄게 4 support
# 갱와봐개때려줄게 5 mid
# 갱와봐개때려줄게 6 jungle
# 갱와봐개때려줄게 7 mid
# 갱와봐개때려줄게 8 top
# 갱와봐개때려줄게 9 adc
# 갱와봐개때려줄게 10 mid
# 갱와봐개때려줄게 11 jungle
# 갱와봐개때려줄게 12 mid
# 갱와봐개때려줄게 13 top
# 갱와봐개때려줄게 14 mid
# 갱와봐개때려줄게 15 jungle
# 갱와봐개때려줄게 16 jungle
# 갱와봐개때려줄게 17 mid
# 갱와봐개때려줄게 18 jungle
# 갱와봐개때려줄게 19 mid
# 갱와봐개때려줄게 20 jungle
# 갱와봐개때려줄게 21 mid
# 갱와봐개때려줄게 22 jungle
# 갱와봐개때려줄게 23 top
# 갱와봐개때려줄게 24 jungle
# 갱와봐개때려줄게 25 jungle
# 갱와봐개때려줄게 26 adc
# 갱와봐개때려줄게 27 adc
# 갱와봐개때려줄게 28 jungle
# 갱와봐개때려줄게 29 top
# 갱와봐개때려줄게 30 top
# 뿌이잉뿌힝 1 top
# 뿌이잉뿌힝 2 top
# 뿌이잉뿌힝 3 mid
# 뿌이잉뿌힝 4 top
# 뿌이잉뿌힝 5 top
# 뿌이잉뿌힝 6 mid
# 뿌이잉뿌힝 7 jungle
# 뿌이잉뿌힝 8 mid
# 뿌이잉뿌힝 9 mid
# 뿌이잉뿌힝 10 mid
# 뿌이잉뿌힝 11 mid
# 뿌이잉뿌힝 12 mid
# 뿌이잉뿌힝 13 mid
# 뿌이잉뿌힝 14 mid
# 뿌이잉뿌힝 15 top
# 뿌이잉뿌힝 16 jungle
# 뿌이잉뿌힝 17 top
# 뿌이잉뿌힝 18 top
# 뿌이잉뿌힝 19 top
# 뿌이잉뿌힝 20 mid
# 뿌이잉뿌힝 21 top
# 뿌이잉뿌힝 22 jungle
# 뿌이잉뿌힝 23 adc
# 뿌이잉뿌힝 24 top
# 뿌이잉뿌힝 25 top
# 뿌이잉뿌힝 26 mid
# 뿌이잉뿌힝 27 top
# 뿌이잉뿌힝 28 top
# 뿌이잉뿌힝 29 mid
# 뿌이잉뿌힝 30 mid
# 3캠프 1 jungle
# 3캠프 2 jungle
# 3캠프 3 jungle
# 3캠프 4 jungle
# 3캠프 5 jungle
# 3캠프 6 jungle
# 3캠프 7 jungle
# 3캠프 8 jungle
# 3캠프 9 jungle
# 3캠프 10 jungle
# 3캠프 11 jungle
# 3캠프 12 jungle
# 3캠프 13 jungle
# 3캠프 14 jungle
# 3캠프 15 jungle
# 3캠프 16 jungle
# 3캠프 17 jungle
# 3캠프 18 mid
# 3캠프 19 jungle
# 3캠프 20 jungle
# 3캠프 21 jungle
# 3캠프 22 jungle
# 3캠프 23 jungle
# 3캠프 24 jungle
# 3캠프 25 jungle
# 3캠프 26 jungle
# 3캠프 27 jungle
# 3캠프 28 jungle
# 3캠프 29 jungle
# 3캠프 30 jungle
# 내루트따라줘 1 mid
# 내루트따라줘 2 adc
# 내루트따라줘 3 mid
# 내루트따라줘 4 top
# 내루트따라줘 5 jungle
# 내루트따라줘 6 adc
# 내루트따라줘 7 jungle
# 내루트따라줘 8 jungle
# 내루트따라줘 9 jungle
# 내루트따라줘 10 jungle
# 내루트따라줘 11 jungle
# 내루트따라줘 12 jungle
# 내루트따라줘 13 jungle
# 내루트따라줘 14 jungle
# 내루트따라줘 15 jungle
# 내루트따라줘 16 adc
# 내루트따라줘 17 jungle
# 내루트따라줘 18 adc
# 내루트따라줘 19 adc
# 내루트따라줘 20 top
# 내루트따라줘 21 top
# 내루트따라줘 22 top
# 내루트따라줘 23 adc
# 내루트따라줘 24 adc
# 내루트따라줘 25 top
# 내루트따라줘 26 adc
# 내루트따라줘 27 jungle
# 내루트따라줘 28 jungle
# 내루트따라줘 29 top
# 내루트따라줘 30 top
# 앨러뷰쏘머취 1 support
# 앨러뷰쏘머취 2 top
# 앨러뷰쏘머취 3 adc
# 앨러뷰쏘머취 4 adc
# 앨러뷰쏘머취 5 mid
# ...
# 너의미소그리워 22 mid
# 너의미소그리워 23 mid
# 너의미소그리워 24 mid
# 너의미소그리워 25 mid
# 너의미소그리워 26 mid
# 너의미소그리워 27 mid
# 너의미소그리워 28 mid
# 작투 1 top
# 작투 2 top
# 작투 3 top
# 작투 4 top
# 작투 5 top
# 작투 6 top
# 작투 7 mid
# 작투 8 top
# 작투 9 top
# 작투 10 top
# 작투 11 top
# 작투 12 mid
# 작투 13 top
# 작투 14 top
# 작투 15 top
# 작투 16 top
# 작투 17 top
# 작투 18 top
# 작투 19 mid
# 작투 20 top
# 작투 21 top
# 작투 22 top
# 작투 23 mid
# 작투 24 top
# 작투 25 top
# 작투 26 top
# 작투 27 top
# 작투 28 mid
# 작투 29 mid
# 작투 30 mid
# 적발 1 support
# 적발 2 support
# 적발 3 support
# 적발 4 support
# 적발 5 support
# 적발 6 support
# 적발 7 support
# 적발 8 support
# 적발 9 support
# 적발 10 support
# 적발 11 support
# 적발 12 support
# 적발 13 support
# 적발 14 support
# 적발 15 support
# 적발 16 support
# 적발 17 support
# 적발 18 support
# 적발 19 support
# 적발 20 support
# 적발 21 support
# 적발 22 support
# 적발 23 support
# 적발 24 support
# 적발 25 support
# 적발 26 support
# 적발 27 support
# 적발 28 support
# 적발 29 mid
# 적발 30 support
# Gastly 1 top
# Gastly 2 top
# Gastly 3 mid
# Gastly 4 mid
# Gastly 5 mid
# Gastly 6 mid
# Gastly 7 mid
# Gastly 8 mid
# Gastly 9 mid
# Gastly 10 adc
# Gastly 11 adc
# Gastly 12 adc
# Gastly 13 jungle
# Gastly 14 adc
# Gastly 15 top
# Gastly 16 mid
# Gastly 17 mid
# Gastly 18 mid
# Gastly 19 top
# Gastly 20 jungle
# Gastly 21 mid
# Gastly 22 mid
# Gastly 23 adc
# Gastly 24 mid
# Gastly 25 mid
# Gastly 26 mid
# Gastly 27 support
# Gastly 28 jungle
# Gastly 29 mid
# Gastly 30 mid
# 겨털덮밥 1 adc
# 겨털덮밥 2 jungle
# 겨털덮밥 3 adc
# 겨털덮밥 4 jungle
# 겨털덮밥 5 top
# 겨털덮밥 6 adc
# 겨털덮밥 7 jungle
# 겨털덮밥 8 top
# 겨털덮밥 9 mid
# 겨털덮밥 10 support
# 겨털덮밥 11 mid
# 겨털덮밥 12 support
# 겨털덮밥 13 support
# 겨털덮밥 14 adc
# 겨털덮밥 15 support
# 겨털덮밥 16 support
# 겨털덮밥 17 jungle
# 겨털덮밥 18 mid
# 겨털덮밥 19 jungle
# 겨털덮밥 20 adc
# 겨털덮밥 21 jungle
# 겨털덮밥 22 jungle
# 겨털덮밥 23 support
# 겨털덮밥 24 adc
# 겨털덮밥 25 mid
# 겨털덮밥 26 mid
# 겨털덮밥 27 adc
# 겨털덮밥 28 adc
# 겨털덮밥 29 support
# 겨털덮밥 30 jungle
# 킹룡칸 1 support
# 킹룡칸 2 mid
# 킹룡칸 3 adc
# 킹룡칸 4 top
# 킹룡칸 5 jungle
# 킹룡칸 6 jungle
# 킹룡칸 7 jungle
# 킹룡칸 8 jungle
# 킹룡칸 9 jungle
# 킹룡칸 10 jungle
# 킹룡칸 11 jungle
# 킹룡칸 12 jungle
# 킹룡칸 13 jungle
# 킹룡칸 14 jungle
# 킹룡칸 15 jungle
# 킹룡칸 16 jungle
# 킹룡칸 17 jungle
# 킹룡칸 18 jungle
# 킹룡칸 19 jungle
# 킹룡칸 20 jungle
# 킹룡칸 21 jungle
# 킹룡칸 22 jungle
# 킹룡칸 23 jungle
# 킹룡칸 24 jungle
# 킹룡칸 25 adc
# 킹룡칸 26 jungle
# 킹룡칸 27 mid
# 킹룡칸 28 jungle
# 킹룡칸 29 jungle
# 킹룡칸 30 jungle
# 개꿀맛티모 1 top
# 개꿀맛티모 2 top
# 개꿀맛티모 3 top
# 개꿀맛티모 4 top
# 개꿀맛티모 5 adc
# 개꿀맛티모 6 top
# 개꿀맛티모 7 mid
# 개꿀맛티모 8 adc
# 개꿀맛티모 9 jungle
# 개꿀맛티모 10 support
# 개꿀맛티모 11 support
# 개꿀맛티모 12 adc
# 개꿀맛티모 13 top
# 개꿀맛티모 14 top
# 개꿀맛티모 15 mid
# 개꿀맛티모 16 jungle
# 개꿀맛티모 17 support
# 개꿀맛티모 18 support
# 개꿀맛티모 19 support
# 개꿀맛티모 20 adc
# 개꿀맛티모 21 adc
# 개꿀맛티모 22 support
# 개꿀맛티모 23 adc
# 개꿀맛티모 24 adc
# 개꿀맛티모 25 adc
# 개꿀맛티모 26 support
# 개꿀맛티모 27 jungle
# 개꿀맛티모 28 support
# 개꿀맛티모 29 adc
# 개꿀맛티모 30 adc
# 마법철퇴 1 adc
# 마법철퇴 2 support
# 마법철퇴 3 jungle
# 마법철퇴 4 adc
# 마법철퇴 5 mid
# 마법철퇴 6 jungle
# 마법철퇴 7 top
# 마법철퇴 8 jungle
# 마법철퇴 9 jungle
# 마법철퇴 10 mid
# 마법철퇴 11 mid
# 마법철퇴 12 jungle
# 마법철퇴 13 jungle
# 마법철퇴 14 jungle
# 마법철퇴 15 top
# 마법철퇴 16 mid
# 마법철퇴 17 top
# 마법철퇴 18 jungle
# 마법철퇴 19 mid
# 마법철퇴 20 adc
# 마법철퇴 21 mid
# 마법철퇴 22 mid
# 마법철퇴 23 mid
# 마법철퇴 24 mid
# 마법철퇴 25 mid
# 마법철퇴 26 mid
# 마법철퇴 27 mid
# 마법철퇴 28 adc
# 마법철퇴 29 adc
# 에똴 1 mid
# 에똴 2 mid
# 에똴 3 adc
# 에똴 4 adc
# 에똴 5 adc
# 에똴 6 adc
# 에똴 7 adc
# 에똴 8 adc
# 에똴 9 adc
# 에똴 10 adc
# 에똴 11 adc
# 에똴 12 adc
# 에똴 13 adc
# 에똴 14 adc
# 에똴 15 adc
# 에똴 16 adc
# 에똴 17 adc
# 에똴 18 adc
# 에똴 19 adc
# 에똴 20 adc
# 에똴 21 adc
# 에똴 22 adc
# 에똴 23 adc
# 에똴 24 adc
# 에똴 25 adc
# 에똴 26 adc
# 에똴 27 adc
# 에똴 28 adc
# 에똴 29 adc
# 에똴 30 adc
# KindredBow 1 jungle
# KindredBow 2 jungle
# KindredBow 3 jungle
# KindredBow 4 jungle
# KindredBow 5 jungle
# KindredBow 6 jungle
# KindredBow 7 jungle
# KindredBow 8 jungle
# KindredBow 9 jungle
# KindredBow 10 jungle
# KindredBow 11 jungle
# KindredBow 12 jungle
# KindredBow 13 jungle
# KindredBow 14 jungle
# KindredBow 15 jungle
# KindredBow 16 jungle
# KindredBow 17 jungle
# KindredBow 18 jungle
# KindredBow 19 jungle
# KindredBow 20 jungle
# KindredBow 21 jungle
# KindredBow 22 jungle
# KindredBow 23 jungle
# KindredBow 24 jungle
# KindredBow 25 jungle
# KindredBow 26 jungle
# KindredBow 27 jungle
# KindredBow 28 jungle
# KindredBow 29 jungle
# KindredBow 30 jungle
# 아씨왜들어갔지 1 top
# 아씨왜들어갔지 2 support
# 아씨왜들어갔지 3 top
# 아씨왜들어갔지 4 jungle
# 아씨왜들어갔지 5 top
# 아씨왜들어갔지 6 top
# 아씨왜들어갔지 7 top
# 아씨왜들어갔지 8 adc
# 아씨왜들어갔지 9 top
# 아씨왜들어갔지 10 top
# 아씨왜들어갔지 11 top
# 아씨왜들어갔지 12 top
# 아씨왜들어갔지 13 jungle
# 아씨왜들어갔지 14 top
# 아씨왜들어갔지 15 top
# 아씨왜들어갔지 16 top
# 아씨왜들어갔지 17 support
# 아씨왜들어갔지 18 adc
# 아씨왜들어갔지 19 adc
# 아씨왜들어갔지 20 mid
# 아씨왜들어갔지 21 adc
# 아씨왜들어갔지 22 adc
# 아씨왜들어갔지 23 adc
# 아씨왜들어갔지 24 adc
# 아씨왜들어갔지 25 adc
# 아씨왜들어갔지 26 adc
# 아씨왜들어갔지 27 adc
# 아씨왜들어갔지 28 adc
# 아씨왜들어갔지 29 adc
# 아씨왜들어갔지 30 adc
# 빼미규 1 jungle
# 빼미규 2 jungle
# 빼미규 3 jungle
# 빼미규 4 jungle
# 빼미규 5 mid
# 빼미규 6 top
# 빼미규 7 top
# 빼미규 8 jungle
# 빼미규 9 jungle
# 빼미규 10 jungle
# 빼미규 11 jungle
# 빼미규 12 jungle
# 빼미규 13 jungle
# 빼미규 14 jungle
# 빼미규 15 top
# 빼미규 16 top
# 빼미규 17 top
# 빼미규 18 top
# 빼미규 19 jungle
# 빼미규 20 jungle
# 빼미규 21 jungle
# 빼미규 22 support
# 빼미규 23 support
# 빼미규 24 adc
# 빼미규 25 mid
# 빼미규 26 top
# 빼미규 27 jungle
# 빼미규 28 jungle
# 빼미규 29 jungle
# 빼미규 30 top
# 편견없는사람 1 mid
# 편견없는사람 2 top
# 편견없는사람 3 top
# 편견없는사람 4 top
# 편견없는사람 5 adc
# 편견없는사람 6 top
# 편견없는사람 7 adc
# 편견없는사람 8 top
# 편견없는사람 9 top
# 편견없는사람 10 top
# 편견없는사람 11 top
# 편견없는사람 12 top
# 편견없는사람 13 top
# 편견없는사람 14 jungle
# 편견없는사람 15 support
# 편견없는사람 16 jungle
# 편견없는사람 17 mid
# 편견없는사람 18 mid
# 편견없는사람 19 mid
# 편견없는사람 20 adc
# 편견없는사람 21 jungle
# 편견없는사람 22 support
# 편견없는사람 23 adc
# 편견없는사람 24 adc
# 편견없는사람 25 jungle
# 편견없는사람 26 top
# 편견없는사람 27 top
# 편견없는사람 28 top
# 편견없는사람 29 adc
# 편견없는사람 30 top
# 다빈이닷 1 adc
# 다빈이닷 2 mid
# 다빈이닷 3 mid
# 다빈이닷 4 mid
# 다빈이닷 5 adc
# 다빈이닷 6 jungle
# 다빈이닷 7 top
# 다빈이닷 8 mid
# 다빈이닷 9 support
# 다빈이닷 10 mid
# 다빈이닷 11 mid
# 다빈이닷 12 mid
# 다빈이닷 13 mid
# 다빈이닷 14 adc
# 다빈이닷 15 mid
# 다빈이닷 16 jungle
# 다빈이닷 17 adc
# 다빈이닷 18 adc
# 다빈이닷 19 mid
# 다빈이닷 20 support
# 다빈이닷 21 jungle
# 다빈이닷 22 mid
# 다빈이닷 23 mid
# 다빈이닷 24 support
# 다빈이닷 25 mid
# 다빈이닷 26 jungle
# 다빈이닷 27 jungle
# 다빈이닷 28 jungle
# 다빈이닷 29 top
# 다빈이닷 30 mid
# Cookiewow 1 adc
# Cookiewow 2 mid
# Cookiewow 3 support
# Cookiewow 4 adc
# Cookiewow 5 jungle
# Cookiewow 6 jungle
# Cookiewow 7 jungle
# Cookiewow 8 adc
# Cookiewow 9 adc
# Cookiewow 10 adc
# Cookiewow 11 top
# Cookiewow 12 adc
# Cookiewow 13 adc
# Cookiewow 14 mid
# Cookiewow 15 mid
# Cookiewow 16 adc
# Cookiewow 17 adc
# Cookiewow 18 jungle
# Cookiewow 19 adc
# Cookiewow 20 adc
# Cookiewow 21 adc
# Cookiewow 22 adc
# Cookiewow 23 adc
# Cookiewow 24 jungle
# Cookiewow 25 mid
# Cookiewow 26 top
# Cookiewow 27 top
# Cookiewow 28 jungle
# Cookiewow 29 mid
# Cookiewow 30 support
# 이곳이어디죠 1 top
# 이곳이어디죠 2 top
# 이곳이어디죠 3 top
# 이곳이어디죠 4 top
# 이곳이어디죠 5 jungle
# 이곳이어디죠 6 mid
# 이곳이어디죠 7 mid
# 이곳이어디죠 8 top
# 이곳이어디죠 9 support
# 이곳이어디죠 10 mid
# 이곳이어디죠 11 mid
# 이곳이어디죠 12 jungle
# 이곳이어디죠 13 mid
# 이곳이어디죠 14 mid
# 이곳이어디죠 15 mid
# 이곳이어디죠 16 mid
# 이곳이어디죠 17 mid
# 이곳이어디죠 18 mid
# 이곳이어디죠 19 jungle
# 이곳이어디죠 20 mid
# 이곳이어디죠 21 mid
# 이곳이어디죠 22 mid
# 이곳이어디죠 23 jungle
# 이곳이어디죠 24 jungle
# 이곳이어디죠 25 jungle
# 이곳이어디죠 26 mid
# 이곳이어디죠 27 jungle
# 이곳이어디죠 28 jungle
# 이곳이어디죠 29 jungle
# 이곳이어디죠 30 jungle
# JPL 1 top
# JPL 2 adc
# JPL 3 adc
# JPL 4 adc
# JPL 5 support
# JPL 6 support
# JPL 7 support
# JPL 8 mid
# JPL 9 top
# JPL 10 support
# JPL 11 support
# JPL 12 support
# JPL 13 support
# JPL 14 adc
# JPL 15 top
# JPL 16 top
# JPL 17 top
# JPL 18 jungle
# JPL 19 adc
# JPL 20 adc
# JPL 21 support
# JPL 22 adc
# JPL 23 adc
# JPL 24 mid
# JPL 25 mid
# JPL 26 mid
# JPL 27 mid
# JPL 28 top
# JPL 29 top
# JPL 30 top
# 삠뿡삥 1 support
# 삠뿡삥 2 support
# 삠뿡삥 3 support
# 삠뿡삥 4 jungle
# 삠뿡삥 5 adc
# 삠뿡삥 6 adc
# 삠뿡삥 7 adc
# 삠뿡삥 8 adc
# 삠뿡삥 9 adc
# 삠뿡삥 10 adc
# 삠뿡삥 11 adc
# 삠뿡삥 12 adc
# 삠뿡삥 13 adc
# 삠뿡삥 14 adc
# 삠뿡삥 15 adc
# 삠뿡삥 16 adc
# 삠뿡삥 17 adc
# 삠뿡삥 18 support
# 삠뿡삥 19 adc
# 삠뿡삥 20 adc
# 삠뿡삥 21 adc
# 삠뿡삥 22 adc
# 삠뿡삥 23 support
# 삠뿡삥 24 support
# 삠뿡삥 25 support
# 삠뿡삥 26 adc
# 삠뿡삥 27 adc
# 삠뿡삥 28 support
# 삠뿡삥 29 support
# 삠뿡삥 30 support
# 리오레접대 1 jungle
# 리오레접대 2 top
# 리오레접대 3 mid
# 리오레접대 4 support
# 리오레접대 5 jungle
# 리오레접대 6 adc
# 리오레접대 7 support
# 리오레접대 8 support
# 리오레접대 9 jungle
# 리오레접대 10 mid
# 리오레접대 11 support
# 리오레접대 12 jungle
# 리오레접대 13 support
# 리오레접대 14 jungle
# 리오레접대 15 mid
# 리오레접대 16 adc
# 리오레접대 17 support
# 리오레접대 18 support
# 리오레접대 19 support
# 리오레접대 20 mid
# 리오레접대 21 jungle
# 리오레접대 22 adc
# 리오레접대 23 jungle
# 리오레접대 24 jungle
# 리오레접대 25 jungle
# 리오레접대 26 mid
# 리오레접대 27 jungle
# 리오레접대 28 jungle
# 리오레접대 29 jungle
# 리오레접대 30 jungle
# 김팡석 1 adc
# 김팡석 2 adc
# 김팡석 3 jungle
# 김팡석 4 jungle
# 김팡석 5 top
# 김팡석 6 adc
# 김팡석 7 jungle
# 김팡석 8 jungle
# 김팡석 9 jungle
# 김팡석 10 top
# 김팡석 11 mid
# 김팡석 12 adc
# 김팡석 13 adc
# 김팡석 14 adc
# 김팡석 15 mid
# 김팡석 16 jungle
# 김팡석 17 support
# 김팡석 18 support
# 김팡석 19 jungle
# 김팡석 20 support
# 김팡석 21 adc
# 김팡석 22 jungle
# 김팡석 23 jungle
# 김팡석 24 adc
# 김팡석 25 jungle
# 김팡석 26 jungle
# 김팡석 27 support
# 김팡석 28 jungle
# 김팡석 29 support
# 김팡석 30 support
# 만두좀 1 jungle
# 만두좀 2 jungle
# 만두좀 3 top
# 만두좀 4 support
# 만두좀 5 jungle
# 만두좀 6 mid
# 만두좀 7 jungle
# 만두좀 8 support
# 만두좀 9 support
# 만두좀 10 jungle
# 만두좀 11 mid
# 만두좀 12 adc
# 만두좀 13 mid
# 만두좀 14 adc
# 만두좀 15 support
# 만두좀 16 jungle
# 만두좀 17 jungle
# 만두좀 18 jungle
# 만두좀 19 jungle
# 만두좀 20 jungle
# 만두좀 21 jungle
# 만두좀 22 mid
# 만두좀 23 support
# 만두좀 24 mid
# 만두좀 25 support
# 만두좀 26 mid
# 만두좀 27 jungle
# 만두좀 28 adc
# 만두좀 29 support
# 만두좀 30 support
# 강은휘 1 jungle
# 강은휘 2 jungle
# 강은휘 3 jungle
# 강은휘 4 mid
# 강은휘 5 adc
# 강은휘 6 jungle
# 강은휘 7 jungle
# 강은휘 8 jungle
# 강은휘 9 jungle
# 강은휘 10 mid
# 강은휘 11 jungle
# 강은휘 12 mid
# 강은휘 13 jungle
# 강은휘 14 jungle
# 강은휘 15 mid
# 강은휘 16 mid
# 강은휘 17 jungle
# 강은휘 18 jungle
# 강은휘 19 mid
# 강은휘 20 mid
# 강은휘 21 jungle
# 강은휘 22 jungle
# 강은휘 23 jungle
# 강은휘 24 jungle
# 강은휘 25 jungle
# jigunmaster 1 mid
# jigunmaster 2 adc
# jigunmaster 3 jungle
# jigunmaster 4 top
# jigunmaster 5 top
# jigunmaster 6 top
# jigunmaster 7 support
# jigunmaster 8 top
# jigunmaster 9 adc
# jigunmaster 10 adc
# jigunmaster 11 mid
# jigunmaster 12 jungle
# jigunmaster 13 support
# jigunmaster 14 top
# jigunmaster 15 top
# jigunmaster 16 top
# jigunmaster 17 support
# jigunmaster 18 support
# jigunmaster 19 mid
# jigunmaster 20 top
# jigunmaster 21 top
# jigunmaster 22 top
# jigunmaster 23 top
# jigunmaster 24 top
# jigunmaster 25 top
# jigunmaster 26 adc
# jigunmaster 27 support
# jigunmaster 28 top
# jigunmaster 29 support
# jigunmaster 30 top
# Azestar 1 adc
# Azestar 2 top
# Azestar 3 mid
# Azestar 4 top
# Azestar 5 adc
# Azestar 6 top
# Azestar 7 top
# Azestar 8 top
# Azestar 9 adc
# Azestar 10 adc
# Azestar 11 adc
# Azestar 12 adc
# Azestar 13 support
# Azestar 14 adc
# Azestar 15 top
# Azestar 16 adc
# Azestar 17 top
# Azestar 18 adc
# Azestar 19 adc
# Azestar 20 adc
# Azestar 21 adc
# Azestar 22 jungle
# Azestar 23 top
# Azestar 24 adc
# Azestar 25 adc
# Azestar 26 adc
# Azestar 27 adc
# Azestar 28 adc
# Azestar 29 adc
# Azestar 30 mid
# 또2또2 1 jungle
# 또2또2 2 support
# 또2또2 3 adc
# 또2또2 4 adc
# 또2또2 5 adc
# 또2또2 6 adc
# 또2또2 7 support
# 또2또2 8 adc
# 또2또2 9 adc
# 또2또2 10 jungle
# 또2또2 11 jungle
# 또2또2 12 adc
# 또2또2 13 adc
# 또2또2 14 adc
# 또2또2 15 jungle
# 또2또2 16 adc
# 또2또2 17 adc
# 또2또2 18 adc
# 또2또2 19 top
# 또2또2 20 jungle
# 또2또2 21 adc
# 또2또2 22 adc
# 또2또2 23 adc
# 또2또2 24 adc
# 또2또2 25 adc
# 또2또2 26 jungle
# 또2또2 27 adc
# 또2또2 28 adc
# 또2또2 29 adc
# 또2또2 30 adc
# 맛스타주세요 1 top
# 맛스타주세요 2 top
# 맛스타주세요 3 support
# 맛스타주세요 4 support
# 맛스타주세요 5 mid
# 맛스타주세요 6 mid
# 맛스타주세요 7 jungle
# 맛스타주세요 8 mid
# 맛스타주세요 9 mid
# 맛스타주세요 10 support
# 맛스타주세요 11 mid
# 맛스타주세요 12 top
# 맛스타주세요 13 mid
# 맛스타주세요 14 mid
# 맛스타주세요 15 mid
# 맛스타주세요 16 mid
# 맛스타주세요 17 mid
# 맛스타주세요 18 mid
# 맛스타주세요 19 top
# 맛스타주세요 20 mid
# 맛스타주세요 21 mid
# 맛스타주세요 22 mid
# 맛스타주세요 23 mid
# 맛스타주세요 24 mid
# 맛스타주세요 25 jungle
# 맛스타주세요 26 jungle
# 맛스타주세요 27 jungle
# 맛스타주세요 28 jungle
# 맛스타주세요 29 mid
# 맛스타주세요 30 mid
# Dkjhost 1 adc
# Dkjhost 2 mid
# Dkjhost 3 adc
# Dkjhost 4 mid
# Dkjhost 5 mid
# Dkjhost 6 mid
# Dkjhost 7 mid
# Dkjhost 8 mid
# Dkjhost 9 mid
# Dkjhost 10 mid
# Dkjhost 11 mid
# Dkjhost 12 mid
# Dkjhost 13 mid
# Dkjhost 14 mid
# Dkjhost 15 adc
# Dkjhost 16 adc
# Dkjhost 17 adc
# Dkjhost 18 adc
# Dkjhost 19 support
# Dkjhost 20 adc
# Dkjhost 21 adc
# Dkjhost 22 adc
# Dkjhost 23 adc
# Dkjhost 24 adc
# Dkjhost 25 adc
# Dkjhost 26 adc
# Dkjhost 27 adc
# Dkjhost 28 adc
# Dkjhost 29 adc
# Dkjhost 30 adc
# 힌둥교 1 mid
# 힌둥교 2 top
# 힌둥교 3 mid
# 힌둥교 4 mid
# 힌둥교 5 mid
# 힌둥교 6 mid
# 힌둥교 7 top
# 힌둥교 8 mid
# 힌둥교 9 mid
# 힌둥교 10 mid
# 힌둥교 11 mid
# 힌둥교 12 mid
# 힌둥교 13 mid
# 힌둥교 14 mid
# 힌둥교 15 mid
# 힌둥교 16 mid
# 힌둥교 17 mid
# 힌둥교 18 mid
# 힌둥교 19 adc
# 힌둥교 20 top
# 힌둥교 21 support
# 힌둥교 22 support
# 힌둥교 23 adc
# 힌둥교 24 mid
# 힌둥교 25 mid
# 힌둥교 26 mid
# 힌둥교 27 adc
# 힌둥교 28 jungle
# 힌둥교 29 top
# 힌둥교 30 top
# 정글차이달달하고 1 support
# 정글차이달달하고 2 support
# 정글차이달달하고 3 support
# 정글차이달달하고 4 support
# 정글차이달달하고 5 support
# 정글차이달달하고 6 support
# 정글차이달달하고 7 support
# 정글차이달달하고 8 support
# 정글차이달달하고 9 mid
# 정글차이달달하고 10 support
# 정글차이달달하고 11 support
# 정글차이달달하고 12 top
# 정글차이달달하고 13 top
# 정글차이달달하고 14 adc
# 정글차이달달하고 15 support
# 정글차이달달하고 16 support
# 정글차이달달하고 17 support
# 정글차이달달하고 18 support
# 정글차이달달하고 19 support
# 정글차이달달하고 20 support
# 정글차이달달하고 21 support
# 정글차이달달하고 22 support
# 정글차이달달하고 23 support
# 정글차이달달하고 24 support
# 정글차이달달하고 25 support
# 정글차이달달하고 26 support
# 정글차이달달하고 27 support
# 정글차이달달하고 28 support
# 정글차이달달하고 29 support
# 정글차이달달하고 30 support
# 욕설 1 jungle
# 욕설 2 jungle
# 욕설 3 jungle
# 욕설 4 mid
# 욕설 5 mid
# 욕설 6 top
# 욕설 7 adc
# 욕설 8 mid
# 욕설 9 jungle
# 욕설 10 jungle
# 욕설 11 jungle
# 욕설 12 mid
# 욕설 13 mid
# 욕설 14 mid
# 욕설 15 top
# 욕설 16 mid
# 욕설 17 mid
# 욕설 18 top
# 욕설 19 adc
# 욕설 20 jungle
# 욕설 21 adc
# 욕설 22 mid
# 욕설 23 jungle
# 욕설 24 jungle
# 욕설 25 jungle
# 욕설 26 jungle
# 욕설 27 mid
# 욕설 28 mid
# 욕설 29 mid
# 욕설 30 jungle
# 아놔트롤인데 1 mid
# 아놔트롤인데 2 support
# 아놔트롤인데 3 support
# 아놔트롤인데 4 support
# 아놔트롤인데 5 support
# 아놔트롤인데 6 mid
# 아놔트롤인데 7 top
# 아놔트롤인데 8 top
# 아놔트롤인데 9 mid
# 아놔트롤인데 10 mid
# 아놔트롤인데 11 top
# 아놔트롤인데 12 support
# 아놔트롤인데 13 support
# 아놔트롤인데 14 adc
# 아놔트롤인데 15 adc
# 아놔트롤인데 16 mid
# 아놔트롤인데 17 support
# 아놔트롤인데 18 top
# 아놔트롤인데 19 adc
# 아놔트롤인데 20 support
# 아놔트롤인데 21 adc
# 아놔트롤인데 22 mid
# 아놔트롤인데 23 top
# 아놔트롤인데 24 mid
# 아놔트롤인데 25 support
# 아놔트롤인데 26 top
# 아놔트롤인데 27 adc
# 아놔트롤인데 28 adc
# 아놔트롤인데 29 adc
# hideoncondom 1 top
# hideoncondom 2 top
# hideoncondom 3 mid
# hideoncondom 4 mid
# hideoncondom 5 top
# hideoncondom 6 top
# hideoncondom 7 mid
# hideoncondom 8 mid
# hideoncondom 9 jungle
# hideoncondom 10 support
# hideoncondom 11 support
# hideoncondom 12 jungle
# hideoncondom 13 top
# hideoncondom 14 top
# hideoncondom 15 top
# hideoncondom 16 mid
# hideoncondom 17 mid
# hideoncondom 18 support
# hideoncondom 19 mid
# hideoncondom 20 adc
# hideoncondom 21 top
# hideoncondom 22 top
# hideoncondom 23 support
# hideoncondom 24 support
# hideoncondom 25 top
# hideoncondom 26 top
# hideoncondom 27 top
# hideoncondom 28 adc
# hideoncondom 29 support
# hideoncondom 30 mid
# 7grand 1 mid
# 7grand 2 adc
# 7grand 3 top
# 7grand 4 mid
# 7grand 5 mid
# 7grand 6 top
# 7grand 7 support
# 7grand 8 top
# 7grand 9 adc
# 7grand 10 mid
# 7grand 11 mid
# 7grand 12 mid
# 7grand 13 top
# 7grand 14 mid
# 7grand 15 top
# 7grand 16 mid
# 7grand 17 top
# 7grand 18 mid
# 7grand 19 mid
# 7grand 20 top
# jinnnnny 1 mid
# jinnnnny 2 mid
# jinnnnny 3 adc
# jinnnnny 4 adc
# jinnnnny 5 jungle
# jinnnnny 6 mid
# jinnnnny 7 adc
# jinnnnny 8 mid
# jinnnnny 9 adc
# jinnnnny 10 adc
# jinnnnny 11 jungle
# jinnnnny 12 jungle
# jinnnnny 13 jungle
# jinnnnny 14 support
# jinnnnny 15 support
# jinnnnny 16 jungle
# jinnnnny 17 adc
# jinnnnny 18 adc
# jinnnnny 19 adc
# jinnnnny 20 adc
# jinnnnny 21 adc
# jinnnnny 22 adc
# jinnnnny 23 adc
# jinnnnny 24 adc
# jinnnnny 25 adc
# jinnnnny 26 adc
# jinnnnny 27 mid
# jinnnnny 28 mid
# jinnnnny 29 adc
# jinnnnny 30 adc
# 초코빠잉 1 adc
# 초코빠잉 2 top
# 초코빠잉 3 adc
# 초코빠잉 4 top
# 초코빠잉 5 adc
# 초코빠잉 6 mid
# 초코빠잉 7 support
# 초코빠잉 8 adc
# 초코빠잉 9 support
# 초코빠잉 10 top
# 초코빠잉 11 jungle
# 초코빠잉 12 support
# 초코빠잉 13 support
# 초코빠잉 14 top
# 초코빠잉 15 adc
# 초코빠잉 16 support
# 초코빠잉 17 support
# 초코빠잉 18 support
# 초코빠잉 19 support
# 초코빠잉 20 top
# 초코빠잉 21 jungle
# 초코빠잉 22 adc
# 초코빠잉 23 jungle
# 초코빠잉 24 support
# 초코빠잉 25 support
# 초코빠잉 26 support
# 초코빠잉 27 adc
# 초코빠잉 28 top
# 초코빠잉 29 jungle
# 초코빠잉 30 support
# AdiosNightMare 1 top
# AdiosNightMare 2 mid
# AdiosNightMare 3 top
# AdiosNightMare 4 top
# AdiosNightMare 5 jungle
# AdiosNightMare 6 adc
# AdiosNightMare 7 mid
# AdiosNightMare 8 adc
# AdiosNightMare 9 adc
# AdiosNightMare 10 adc
# AdiosNightMare 11 adc
# AdiosNightMare 12 adc
# AdiosNightMare 13 adc
# AdiosNightMare 14 jungle
# AdiosNightMare 15 support
# AdiosNightMare 16 jungle
# AdiosNightMare 17 jungle
# AdiosNightMare 18 adc
# AdiosNightMare 19 jungle
# AdiosNightMare 20 support
# AdiosNightMare 21 jungle
# AdiosNightMare 22 support
# AdiosNightMare 23 jungle
# AdiosNightMare 24 top
# AdiosNightMare 25 jungle
# AdiosNightMare 26 adc
# AdiosNightMare 27 support
# AdiosNightMare 28 support
# AdiosNightMare 29 mid
# AdiosNightMare 30 support
# 노시눙 1 mid
# 노시눙 2 support
# 노시눙 3 adc
# 노시눙 4 mid
# 노시눙 5 adc
# 노시눙 6 support
# 노시눙 7 mid
# 노시눙 8 mid
# 노시눙 9 mid
# 노시눙 10 top
# 노시눙 11 jungle
# 노시눙 12 adc
# 노시눙 13 mid
# 노시눙 14 top
# 노시눙 15 top
# 노시눙 16 mid
# 노시눙 17 adc
# 노시눙 18 adc
# 노시눙 19 adc
# 노시눙 20 adc
# 노시눙 21 top
# 노시눙 22 mid
# 노시눙 23 adc
# 노시눙 24 adc
# 노시눙 25 top
# 노시눙 26 top
# 노시눙 27 mid
# 노시눙 28 mid
# 노시눙 29 jungle
# 노시눙 30 adc
# 아정글차이5지네 1 mid
# 아정글차이5지네 2 mid
# 아정글차이5지네 3 mid
# 아정글차이5지네 4 mid
# 아정글차이5지네 5 mid
# 아정글차이5지네 6 mid
# 아정글차이5지네 7 top
# 아정글차이5지네 8 mid
# 아정글차이5지네 9 mid
# 아정글차이5지네 10 support
# 아정글차이5지네 11 support
# 아정글차이5지네 12 mid
# 아정글차이5지네 13 mid
# 아정글차이5지네 14 mid
# 아정글차이5지네 15 support
# 아정글차이5지네 16 support
# 아정글차이5지네 17 mid
# 아정글차이5지네 18 support
# 아정글차이5지네 19 mid
# 아정글차이5지네 20 mid
# 아정글차이5지네 21 adc
# 아정글차이5지네 22 mid
# 아정글차이5지네 23 mid
# 아정글차이5지네 24 mid
# 아정글차이5지네 25 mid
# 아정글차이5지네 26 mid
# 아정글차이5지네 27 mid
# 아정글차이5지네 28 mid
# 아정글차이5지네 29 mid
# 아정글차이5지네 30 mid
# 4소대장 1 top
# 4소대장 2 support
# 4소대장 3 support
# 4소대장 4 support
# 4소대장 5 jungle
# 4소대장 6 top
# 4소대장 7 mid

# %%
col_nm = ['유저명', '티어', '승패', '챔피언', '포지션', 'Kill', 'Death', 'Assist', '킬관여율']
data = pd.DataFrame(data,columns=col_nm)
data
# Out:
#            유저명        티어    승패      챔피언      포지션 Kill Death Assist  킬관여율
# 0          턱돼지  Bronze 4   WIN  Shyvana   jungle  12     0      4   6.00
# 1          턱돼지  Bronze 4    RE  Shyvana   jungle   0     0       0  0.00
# 2          턱돼지  Bronze 4   WIN  Shyvana   jungle  14     8      24  4.75
# 3          턱돼지  Bronze 4   WIN  Shyvana   jungle  16     7       9  3.57
# 4          턱돼지  Bronze 4  LOSS  Shyvana   jungle  11     4       8  4.75
# ...        ...       ...   ...      ...      ...  ...   ...    ...   ...
# 10384  4 소 대 장  Bronze 1  LOSS    Amumu  support  10    11       3  1.18
# 10385  4 소 대 장  Bronze 1  LOSS  Orianna  support   0    11      10  0.91
# 10386  4 소 대 장  Bronze 1   WIN     Shen   jungle   5     5      23  5.60
# 10387  4 소 대 장  Bronze 1   WIN  Hecarim      top   6     5      10  3.20
# 10388  4 소 대 장  Bronze 1   WIN   Akshan      mid   7     5       7  2.80
#
# [10389 rows x 9 columns]

# %%
data.to_csv('./lol_data_1_500.csv', index=False)

# %%
data.to_excel('./lol_data_1_500.xlsx', index=False)

# %%
data['Kill'].sum()
# Out:
# '12 0 14 16 11 4 6 2 7 13 5 7 10 7 12 10 7 6 7 3 12 3 1 8 12 2 12 14 12 4 5 7 5 3 2 2 6 4 5 2 4 10 0 3 6 1 13 4 9 6 5 19 8 12 13 2 10 6 5 20 2 2 20 17 8 19 8 11 4 12 5 6 6 10 8 4 8 14 16 11 6 12 18 5 7 11 2 18 7 10 27 12 8 6 2 4 2 1 2 1 8 1 2 2 15 10 2 19 6 9 3 10 14 5 5 5 2 4 0 6 13 5 7 1 6 2 2 11 5 5 16 6 2 4 6 4 2 8 2 2 11 5 5 5 3 6 3 3 1 9 6 4 18 13 14 4 10 7 7 2 3 10 4 9 8 23 15 13 2 11 4 4 6 17 11 9 7 7 7 10 7 1 4 17 5 7 3 12 10 6 15 11 8 6 18 15 3 15 2 4 8 9 6 20 3 15 6 6 10 2 9 9 3 14 7 2 5 10 14 4 20 2 9 15 6 5 1 7 8 8 6 13 4 9 2 6 20 18 3 2 12 4 1 9 9 5 4 0 12 12 7 1 3 4 9 8 7 4 5 11 9 10 2 6 12 2 2 8 22 1 5 14 6 8 4 5 5 3 9 7 11 7 4 14 1 9 8 12 9 3 0 6 7 8 8 1 10 10 3 14 8 13 8 4 9 9 7 14 13 14 5 19 6 6 9 9 10 20 5 3 4 2 4 6 10 10 14 8 12 14 8 2 2 3 7 0 7 2 3 3 3 7 8 2 16 13 9 5 2 0 7 22 3 5 16 6 4 3 6 8 0 5 5 4 5 7 1 2 0 2 2 2 7 4 7 15 2 6 3 3 5 7 11 1 27 4 3 2 6 1 3 10 3 11 3 4 5 3 2 5 4 1 3 1 2 2 1 6 12 5 2 10 6 21 5 16 7 5 0 1 5 4 16 13 8 8 12 19 20 2 9 7 16 11 3 15 16 9 11 2 8 7 8 12 9 0 2 16 8 9 5 15 5 5 4 7 10 17 11 16 9 3 0 2 13 6 16 2 1 10 8 7 11 6 9 21 3 8 2 6 21 7 24 3 17 24 14 4 3 12 10 9 7 2 19 6 7 9 9 2 6 9 29 4 9 5 6 10 8 12 10 5 8 1 3 7 1 1 8 1 3 4 1 7 3 4 6 2 5 6 3 3 2 3 6 3 1 2 1 5 11 3 4 8 5 12 6 5 11 10 11 12 9 1 7 3 10 2 11 21 4 8 4 19 6 22 8 2 5 10 0 1 3 10 2 3 1 2 0 3 1 2 4 11 4 2 1 1 3 2 2 2 5 4 2 2 4 1 5 0 7 0 0 1 15 9 10 2 11 5 2 5 7 5 5 4 8 11 5 7 13 1 6 13 7 12 7 9 9 4 2 1 8 3 15 1 4 6 6 14 7 9 4 2 0 2 3 6 15 10 11 8 5 0 13 2 9 9 9 0 6 1 4 0 19 11 14 8 0 6 3 8 0 5 11 9 8 9 18 12 13 9 14 6 5 7 1 15 18 4 2 2 1 0 1 1 0 11 4 4 9 14 4 4 1 2 3 4 0 3 9 6 1 10 4 3 2 5 1 5 8 15 3 4 2 6 13 22 11 13 12 2 19 8 2 10 16 7 1 6 8 1 8 5 18 5 15 10 0 2 9 7 2 6 3 7 17 7 10 0 12 5 18 15 3 3 27 3 9 2 2 18 6 11 6 11 6 5 9 5 2 13 2 16 17 13 10 7 4 2 6 6 6 7 16 6 5 4 3 11 24 10 15 4 8 15 12 4 1 10 13 22 9 6 13 17 15 11 6 12 17 3 13 11 9 12 2 5 14 27 9 9 9 6 6 6 16 11 11 8 14 7 10 18 8 4 8 8 11 7 2 2 2 2 0 5 6 9 5 14 5 3 4 12 13 4 11 17 2 12 17 8 4 3 7 4 14 5 4 9 11 12 5 8 3 1 13 9 7 1 9 5 6 11 7 3 4 6 21 1 4 5 11 13 4 17 4 10 17 10 5 7 10 7 6 17 3 8 3 9 6 10 0 2 0 3 9 11 12 5 8 6 4 2 0 1 4 6 8 15 1 0 2 3 4 7 9 15 8 7 0 1 5 4 4 8 2 9 5 7 1 0 9 3 3 17 14 7 2 3 0 3 6 9 3 5 3 1 0 2 3 6 5 28 11 0 1 3 3 1 8 2 9 0 1 14 2 10 1 7 2 5 0 7 0 0 0 11 0 11 18 7 13 7 7 1 7 5 13 17 2 5 19 19 5 15 5 3 5 2 16 3 9 13 7 13 0 5 8 11 12 6 14 8 4 10 10 10 11 5 4 13 9 9 1 10 8 2 15 6 4 8 24 3 5 2 6 4 4 2 5 17 5 8 15 8 2 8 8 4 3 13 12 10 3 12 6 13 9 17 12 12 5 9 12 4 11 9 8 8 1 4 2 9 7 10 5 11 13 5 12 4 2 7 11 13 11 9 5 9 13 10 2 7 17 5 8 2 8 8 9 9 9 12 0 8 2 10 0 8 3 5 8 5 9 0 2 19 4 16 9 3 12 4 3 16 0 17 10 13 2 4 7 3 6 4 7 6 5 5 10 7 6 5 0 7 8 11 10 2 7 8 3 1 0 8 5 10 0 7 11 3 1 0 5 7 1 15 3 3 1 2 4 10 2 6 8 8 5 3 2 1 4 2 2 4 1 4 7 3 4 10 10 2 23 7 3 8 5 3 4 7 2 2 6 1 0 16 5 4 0 6 2 0 5 5 0 4 4 8 1 9 6 2 3 0 7 4 1 15 0 11 0 1 10 3 3 2 7 5 5 12 7 2 6 2 4 17 11 5 10 11 8 6 11 3 10 8 12 2 8 3 1 5 0 7 9 0 7 8 10 0 3 0 7 4 14 8 5 1 5 6 0 10 11 6 8 6 3 1 1 8 4 1 1 2 0 3 3 0 1 6 3 0 3 12 7 4 7 0 9 10 3 4 1 2 3 4 3 10 13 9 4 1 3 13 13 8 5 2 3 10 3 3 1 3 5 13 5 5 16 5 10 14 18 6 2 12 14 5 14 8 21 11 3 22 4 4 6 3 8 5 5 8 10 14 10 20 12 0 0 0 3 3 4 2 11 11 0 2 5 6 4 5 17 7 15 3 2 6 2 5 3 0 2 6 2 0 5 8 3 2 1 2 0 3 0 3 2 0 7 7 1 13 11 7 4 1 7 7 3 4 4 0 9 9 8 1 0 4 1 6 11 2 0 9 7 3 2 1 1 17 9 6 5 3 0 3 4 2 5 1 2 8 0 11 3 1 2 7 22 19 2 12 8 17 13 12 5 6 10 4 20 24 8 4 7 7 2 1 9 5 2 6 5 7 9 6 17 2 12 8 3 10 13 14 14 9 5 8 1 10 18 2 1 3 2 2 0 4 5 9 2 3 8 2 1 5 1 6 14 4 13 14 7 12 8 9 6 19 22 20 20 5 7 7 6 4 8 9 2 16 10 12 5 4 0 19 9 2 9 14 6 1 16 14 10 8 0 14 6 6 9 15 21 10 3 8 7 14 6 14 4 4 14 13 12 12 9 7 8 9 5 13 2 3 7 4 6 13 12 9 5 18 5 4 0 23 1 3 7 3 2 4 9 5 15 0 6 13 10 3 11 6 13 9 6 6 6 6 7 9 6 7 17 10 13 7 6 15 11 0 6 10 7 1 10 10 4 10 5 6 3 6 1 13 8 16 7 8 0 11 6 4 5 15 6 1 5 2 1 10 10 7 4 3 2 6 5 3 7 11 13 1 4 0 9 3 4 6 19 25 0 2 7 8 13 15 0 6 3 0 2 3 7 3 2 3 5 1 2 2 1 5 3 4 0 7 16 10 3 0 12 8 8 5 7 5 7 7 6 3 4 1 1 0 7 3 4 3 11 1 6 7 1 0 1  ...
