# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import selenium
import requests
import os

# %%
data = []

def data_crawling(user_name):
#DB 유저 불러오기
    url = f'https://your.gg/kr/profile/{user_name}'
    resp = requests.get(url)
    html = BeautifulSoup(resp.text, 'html.parser')
#승패 크롤링
    for i in range(30):
        # 티어 크롤링
        # buiiz7-0 sc-1p3os9u-3 hCTbNr zMKXD
        ingame_id = html.select('div.sc-15xrq75-3 span')[0].text.strip()
        tier = html.select('div span.sc-1p3os9u-3')[0].text.strip()
        # 승, 패 크롤링
        # buiiz7-0 d490eh-4 hCTbML dSQenp
        Win_lose = html.select('span.d490eh-4')[i].text
        # KDA 크롤링
        # buiiz7-0 sc-1p49g2y-1 hNEJCS gLFnks
        KDA = html.select('span.sc-1p49g2y-1')[i*3].text[:-7]
        kill = KDA.split('/')[0]
        death =  KDA.split('/')[1]
        assist = KDA.split('/')[2]
        # 게임 시간 크롤링
        # buiiz7-0 d490eh-5 hNEJEN
        game_time = html.select('span.d490eh-5')[i].text
        # 챔피언 크롤링
        # sc-1xwhuw1-0 afFmu sc-1hmh1k6-4 dIKnaT
        champion =html.select('div.sc-1xwhuw1-0 img')[i*11]['alt']
        # 킬 관여율 크롤링
        kill_pati = html.select('span.sc-1p49g2y-1')[i*3].text[-5:-1]
        # 두번째 방법
        # your.gg의 게임 결과의 우측에 닉네임이 존재하는 순서를 통해 포지션 크롤링 하기
        # d490eh-10 dkiApC
        users = []
        for j in html.select('ul.d490eh-10 a'):
            users.append(j.text)
        if users[10*i:10*(i+1)].index(ingame_id) == 0 or users[10*i:10*(i+1)].index(ingame_id) == 1:
            position = 'top'
        elif users[10*i:10*(i+1)].index(ingame_id) == 2 or users[10*i:10*(i+1)].index(ingame_id) == 3:
            position = 'jungle'
        elif users[10*i:10*(i+1)].index(ingame_id) == 4 or users[10*i:10*(i+1)].index(ingame_id) == 5:
            position = 'mid'
        elif users[10*i:10*(i+1)].index(ingame_id) == 6 or users[10*i:10*(i+1)].index(ingame_id) == 7:
            position = 'adc'
        else:
            position = 'support'
        print(i, position)
        # 0~1 top
        # 2~3 jungle
        # 4~5 mid
        # 6~7 adc
        # 8~9 support
        data.append([ ingame_id, tier, Win_lose, champion, position, kill, death, assist, kill_pati ])
#         return data

# %%
data_crawling('hideonbush')
# Out:
# 0 mid
# 1 mid
# 2 mid
# 3 mid
# 4 mid
# 5 mid
# 6 mid
# 7 mid
# 8 mid
# 9 jungle
# 10 mid
# 11 mid
# 12 mid
# 13 mid
# 14 mid
# 15 top
# 16 mid
# 17 jungle
# 18 mid
# 19 top
# 20 mid
# 21 mid
# 22 top
# 23 mid
# 24 top
# 25 mid
# 26 mid
# 27 top
# 28 mid
# 29 top

# %%
col_nm = ['유저명', '티어', '승패', '챔피언', '포지션', 'Kill', 'Death', 'Assist', '킬관여율']
data = pd.DataFrame(data,columns=col_nm)
data
# Out:
#              유저명          티어    승패          챔피언     포지션 Kill Death Assist  \
# 0   Hide on bush  Challenger   WIN         Ahri     mid   2     4      16
# 1   Hide on bush  Challenger  LOSS         Yone     mid   4     7       4
# 2   Hide on bush  Challenger  LOSS         Ahri     mid   2     5      11
# 3   Hide on bush  Challenger  LOSS       Viktor     mid   1     7       9
# 4   Hide on bush  Challenger   WIN   Cassiopeia     mid   6     4       1
# 5   Hide on bush  Challenger   WIN        Akali     mid  11     2       7
# 6   Hide on bush  Challenger  LOSS        Sylas     mid  10     5       4
# 7   Hide on bush  Challenger  LOSS         Ahri     mid   6     4       6
# 8   Hide on bush  Challenger   WIN        Corki     mid   7     5       4
# 9   Hide on bush  Challenger   WIN      Skarner  jungle   2     3      10
# 10  Hide on bush  Challenger   WIN    Lissandra     mid   3     2       3
# 11  Hide on bush  Challenger   WIN  TwistedFate     mid   3     0       4
# 12  Hide on bush  Challenger  LOSS  TwistedFate     mid   5     3       9
# 13  Hide on bush  Challenger   WIN    Lissandra     mid   4     4      11
# 14  Hide on bush  Challenger   WIN    Lissandra     mid   9     0      9
# 15  Hide on bush  Challenger  LOSS         Gwen     top   2     6       2
# 16  Hide on bush  Challenger   WIN         Zeri     mid   5     1       3
# 17  Hide on bush  Challenger   WIN       LeeSin  jungle  11     7      12
# 18  Hide on bush  Challenger   WIN         Ahri     mid   1     0       2
# 19  Hide on bush  Challenger  LOSS         Gnar     top   3     5       0
# 20  Hide on bush  Challenger   WIN          Zoe     mid   1     2      11
# 21  Hide on bush  Challenger  LOSS          Zoe     mid   2     3       3
# 22  Hide on bush  Challenger  LOSS    Gangplank     top   1     7       3
# 23  Hide on bush  Challenger  LOSS        Swain     mid   1     7       3
# 24  Hide on bush  Challenger   WIN         Gwen     top   5     4      13
# 25  Hide on bush  Challenger  LOSS     Kassadin     mid  12     3       5
# 26  Hide on bush  Challenger   WIN         Azir     mid   3     0       1
# 27  Hide on bush  Challenger   WIN     Vladimir     top   1     1       2
# 28  Hide on bush  Challenger  LOSS        Akali     mid   4     8       1
# 29  Hide on bush  Challenger   WIN         Gwen     top   0     1       0
#
#     킬관여율
# 0   4.50
# 1   1.14
# 2   2.60
# 3   1.43
# 4   1.75
# 5   9.00
# 6   2.80
# 7   3.00
# 8   2.20
# 9   4.00
# 10  3.00
# 11  7.00
# 12  4.67
# 13  3.75
# 14  8.00
# 15  0.67
# 16  8.00
# 17  3.29
# 18  3.00
# 19  0.60
# 20  6.00
# 21  1.67
# 22  0.57
# 23  0.57
# 24  4.50
# 25  5.67
# 26  4.00
# 27  3.00
# 28  0.63
# 29  0.00

# %%
url = f'https://your.gg/kr/profile/hideonbush'
resp = requests.get(url)
html = BeautifulSoup(resp.text, 'html.parser')

users = []
for i in html.select('ul.d490eh-10 a'):
    users.append(i.text)
    
users
# Out:
# ['BRO Soboro',
#  'Lego77',
#  'Night 9 19',
#  '벼랑위너구리',
#  '노는소년카티',
#  'Hide on bush',
#  'ilnvcxz',
#  'Happie',
#  'SMB bangzhu',
#  '농심라면다내꺼야',
#  '오늘도 잠에 든다',
#  'Canna00',
#  ' 7I 인',
#  'Rascal',
#  '27haokan',
#  'Hide on bush',
#  '비둘기랑동거중',
#  'Huyatv Fenghu',
#  '건들지마 심기',
#  '노행준',
#  'twichTV 이현2',
#  'T1 Photon2',
#  'spacecastle',
#  'IGq1749193239',
#  'Pungyeon',
#  'Hide on bush',
#  'Otsuko Yuta',
#  'Conquer yourself',
#  '노행준',
#  'snzll',
#  't0 Make it Count',
#  'Kingen',
#  'Gen G Quid',
#  'Night 9 19',
#  'Seven',
#  'Hide on bush',
#  'Restschnee',
#  'hee98',
#  'I am yours',
#  '솔랭전문서폿',
#  '어리고싶다',
#  'HLE Karis1',
#  '예슬1',
#  '0NER0',
#  'Hide on bush',
#  'zhong men dui ju',
#  'Enosh',
#  'MUDAI',
#  'EveryD EveryM',
#  '역천괴',
#  '농심 디엔디엔',
#  'knightt',
#  '나의 날은 무수히',
#  'SMB heixiaohu',
#  'Hide on bush',
#  'zhong men dui ju',
#  '독기품기',
#  'T1 Gumayusi',
#  'qweadsadd',
#  'V5 R1ch',
#  '수희0',
#  'T1 Zeus',
#  'aIways off',
#  'T1 Gumayusi',
#  'Hide on bush',
#  'eisaaac',
#  'Lumen AD',
#  '난화내',
#  'K a e 1',
#  '티원 에스퍼',
#  'qiqiqi77',
#  'knightt',
#  '어디료든 문',
#  'n1ka',
#  'YAMANGZZ',
#  'Hide on bush',
#  '독을품기 ',
#  '난화내',
#  'DK Bible',
#  'ioplkmjugwacv',
#  'HLE OnFleek',
#  'teddy5',
#  'XiaoHuaSheng7',
#  'beichuan',
#  'Hide on bush',
#  '지훈백크',
#  '가민준',
#  'CCwhitte',
#  '4006114',
#  'BRO Loopy',
#  '아파요 머리가',
#  'HLE OnFleek',
#  'Doing Crazy BRO',
#  'Hide on bush',
#  'ajfqkTLqkfdk',
#  'KDF BuLLDoG',
#  '가민준',
#  'CCwhitte',
#  'zxcvfwwk',
#  'K a e 1',
#  '7Lq L',
#  'zxcasqwas',
#  '124214',
#  'long zhong niao',
#  'Hide on bush',
#  'KDF BuLLDoG',
#  '느린시간속에네온',
#  '가민준',
#  'zxcvfwwk',
#  'BRO Loopy',
#  '7Lq L',
#  'Croco',
#  '124214',
#  'Doing Crazy BRO',
#  'zI존고수짱짱맨',
#  'Hide on bush',
#  '난화내',
#  '비둘기랑동거중',
#  'BRO Delight',
#  '참새크면비둘기',
#  '이도류',
#  'fraglie',
#  'One Last K1ss',
#  'long zhong niao',
#  'Hide on bush',
#  'qiqiqi77',
#  '독을품기 ',
#  'BRO Hena',
#  'Night 9 19',
#  'BRO Delight',
#  '디케이 탑',
#  'BRO Delight',
#  'lnferno',
#  '아 여름이였다',
#  'boongwa',
#  'Hide on bush',
#  'T1 Smash1',
#  'hope3',
#  '재훈이의모함',
#  'zxcvfwwk',
#  'Jianguoqiangzz',
#  '박재범 원소주',
#  'XiaoHuaSheng7',
#  'gggggggg888',
#  'Hide on bush',
#  'CruIserr',
#  '베란다고양이',
#  'BRO Hena',
#  'xxxxxxm',
#  'opasdwqexz',
#  'Hide on bush',
#  '개 무겁다',
#  'n1ka',
#  '독을품기 ',
#  'midqvq',
#  'Gai guo zixin',
#  'daoxinwengu',
#  '헝그리트래블러',
#  'in to a sleep ',
#  'BRO Delight',
#  '경이입니당',
#  'Lego77',
#  'Utopiax',
#  'long zhong niao',
#  'Aileri',
#  'Hide on bush',
#  'Huyatv Fenghu',
#  'T1 Gumayusi',
#  'qweadsadd',
#  'KT Way',
#  '오석19',
#  'lin shu hao',
#  'dadadadududu',
#  'Hide on bush',
#  'Gen G Quid',
#  '27haokan',
#  '미안할지도',
#  'Zui chi bi',
#  'Gen G Akia',
#  'qingxiaohu',
#  '미안할지도',
#  'elbAGMO',
#  '보석스턴건 애디',
#  '124214',
#  'Gai guo zixin',
#  'Hide on bush',
#  'Gen G Akia',
#  'viper3',
#  'casssie',
#  '1타 잔 1',
#  '보석스턴건 애디',
#  'Hide on bush',
#  '124214',
#  'di fen gao neng',
#  'Gai guo zixin',
#  'Gen G Peyz',
#  '1타 잔 1',
#  'zxcvasdfqwerty',
#  'eisaaac',
#  'fcczz',
#  'Kingen',
#  '어리고싶다',
#  'Dan Xiao Gu',
#  'IlllIIIIlIIlIlII',
#  'Hide on bush',
#  '아 여름이였다',
#  '베란다고양이',
#  'tswmyy',
#  '역천괴',
#  'huangshang1',
#  '권지인',
#  '따봉 람머스',
#  'Juhana',
#  'laji you xi',
#  'Hide on bush',
#  'HLE Karis1',
#  'tswmyy',
#  'waiga',
#  '04 09 2530',
#  'qiqiqi77',
#  'qiqiqi77',
#  'Hide on bush',
#  'IlllIIIIlIIlIlII',
#  'laji you xi',
#  'small champ pool',
#  '권지인',
#  'dlrlrhtlvdjdy',
#  'tswmyy',
#  'SwordArt77777',
#  '참새크면비둘기',
#  '존중겸손아닥집중',
#  'huihui love yuki',
#  'IlllIIIIlIIlIlII',
#  'Wkwmdskk',
#  'qiqiqi77',
#  'Hide on bush',
#  'Lumen AD',
#  'zenbukorosu',
#  'SwordArt77777',
#  '금방1',
#  'Gen G Casting',
#  'Hide on bush',
#  'big champ pool',
#  '0NER0',
#  'zI존고수짱짱맨',
#  'KT VicLa',
#  'MUDAI',
#  'guikkl',
#  'Zenbukorosn',
#  '티원 에스퍼',
#  '시금치먹는뽀빠이',
#  'fragiIe',
#  '역시폭군',
#  'n1ka',
#  'Hide on bush',
#  'xiaowanshu',
#  'daoxinwengu',
#  'deokdam',
#  'dia hermoso',
#  'twilignt',
#  'ArkRuHa',
#  'elbAGMO',
#  '124214',
#  '버거킹안양호계점',
#  'YAMANGZZ',
#  'Hide on bush',
#  'Happie',
#  '난왜이렇게살까',
#  'wayyyyy',
#  'EveryD EveryM',
#  'Hide on bush',
#  'ya li guai',
#  'n1ka',
#  '아 여름이였다',
#  'midqvq',
#  'Gen G Quid',
#  'Kerill1an',
#  'hope3',
#  'wayyyyy',
#  'ebhtr',
#  '팀개못하면누누함',
#  '강하다 별',
#  'meiyoudalong',
#  '권지인',
#  'YAMANGZZ',
#  'Hide on bush',
#  'zxcvasdfqwerty',
#  'Zui chi bi',
#  'snzll',
#  'WuNaicuteqaq',
#  'Hide on bush',
#  '팀개못하면누누함',
#  'WeiXinyu',
#  'IlllIIIIlIIlIlII',
#  'KDF BuLLDoG',
#  'itmylike',
#  'Kerill1an',
#  '독을품기 ',
#  '티원 에스퍼',
#  '어디료든 문']

# %%
# div. sc-15xrq75-3 dmdPQ
# span. buiiz7-0 sc-jrQzAO hCTbGX kzqJxc
html.select('div.sc-15xrq75-3 span')[0].text
# Out:
# 'Hide on bush'
