# %%
# 필요패키지 import
import time
import json
import urllib
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup

# %%
#데이터 담는 곳
desc_list = []

for num in range(1,21):
#딜레이    
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(1) + round(np.random.random(),2)
    time.sleep(a)

#욕설신고 게시판 제목 크롤링
    url = f'https://www.inven.co.kr/board/lol/2771?category=%EC%9A%95%EC%84%A4&p={num}'
    resp = requests.get(url)
    html = BeautifulSoup(resp.text, 'html.parser')
    for news in html.select('td.tit'):
        desc_list.append(news.text.strip().replace('\t','').replace('\n',''))

# %%
len(desc_list)
# Out:
# 1200

# %%
nick_list = []
for i in range(0,1200):
    nick_list.append(desc_list[i].split())

# %%
nick_array = np.array(nick_list)
nick_df = pd.DataFrame(nick_list,columns='columns')
# Out:
# C:\Users\Hote\AppData\Local\Temp\ipykernel_6348\1578975321.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   nick_array = np.array(nick_list)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 2>()
#       1 nick_array = np.array(nick_list)
# ----> 2 nick_df = pd.DataFrame(nick_list,columns='columns')
#
# File ~\anaconda3\envs\datascience\lib\site-packages\pandas\core\frame.py:720, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     714 if not isinstance(data, np.ndarray) and treat_as_nested(data):
#     715     # exclude ndarray as we may have cast it a few lines above
#     716     if columns is not None:
# ...

# %%
nick_df
# Out:
#         0         1        2        3     4            5     6     7     8   \
# 0     [욕설]       턱돼지        <       소통  불가능한       사회부적응자  None  None  None
# 1     [욕설]  핑찍으면우물잠수       <<      패드립    박제           사진  None  None  None
# 2     [욕설]       패드립       룰루       브실    구간         None  None  None  None
# 3     [욕설]      이원일,   Visual   Jockey    <<          정치만     할   줄아는    무능
# 4     [욕설]      mvp맨       사진     None  None         None  None  None  None
# ...    ...       ...      ...      ...   ...          ...   ...   ...   ...
# 1195  [욕설]       최찬유       <-     고의트롤   [1]         None  None  None  None
# 1196  [욕설]       닉네임        :   무하마드얄리    신고         None  None  None  None
# 1197  [욕설]    봇빨간사춘기      패드립  박제시킵니다.  None         None  None  None  None
# 1198  [욕설]      인공지능      캣타워        <   배정된          포지션    거부     및    꼴픽
# 1199  [욕설]   [박제]Jea  Hyeon00   위안부드립침   전번깜  01085571284  None  None  None
#
# ...

# %%
nick_df.to_csv('./nick_df.csv', index=False)
